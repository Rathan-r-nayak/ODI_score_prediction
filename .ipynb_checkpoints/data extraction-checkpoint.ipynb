# %%
import numpy as np
import pandas as pd
from yaml import safe_load
import matplotlib.pyplot as plt
import seaborn as sns
import os
from tqdm import tqdm
import pickle

# %%
filenames = []
for file in os.listdir('data'):
    filenames.append(os.path.join('data',file))

# %%
filenames[1:10]
# Out:
# ['data/434260.yaml',
#  'data/587473.yaml',
#  'data/685731.yaml',
#  'data/415284.yaml',
#  'data/1059196.yaml',
#  'data/571947.yaml',
#  'data/392619.yaml',
#  'data/1034823.yaml',
#  'data/527016.yaml']

# %%
final_df = pd.DataFrame()
counter = 1
for file in tqdm(filenames):
    with open(file, 'r') as f:
        df = pd.json_normalize(safe_load(f))
        df['match_id'] = counter
        final_df = pd.concat([final_df, df], ignore_index=True)
        counter+=1
        
final_df
# Out:
# 100%|███████████████████████████████████████| 2033/2033 [09:27<00:00,  3.58it/s]
#                                                 innings  meta.data_version
# 0     [{'1st innings': {'team': 'Ireland', 'deliveri...                0.9  \
# 1     [{'1st innings': {'team': 'Bangladesh', 'deliv...                0.9
# 2     [{'1st innings': {'team': 'Bangladesh', 'deliv...                0.9
# 3     [{'1st innings': {'team': 'Pakistan', 'deliver...                0.9
# 4     [{'1st innings': {'team': 'West Indies', 'deli...                0.9
# ...                                                 ...                ...
# 2028  [{'1st innings': {'team': 'South Africa', 'del...                0.9
# 2029  [{'1st innings': {'team': 'India', 'deliveries...                0.9
# 2030  [{'1st innings': {'team': 'Australia', 'delive...                0.9
# 2031  [{'1st innings': {'team': 'Zimbabwe', 'deliver...                0.9
# 2032  [{'1st innings': {'team': 'West Indies', 'deli...                0.9
#
#      meta.created  meta.revision     info.city    info.dates info.gender
# 0      2019-07-22              1       Belfast  [2019-07-04]        male  \
# 1      2010-01-08              2        Mirpur  [2010-01-07]        male
# 2      2012-12-24              2        Mirpur  [2012-12-05]        male
# 3      2013-11-30              1     Cape Town  [2013-11-24]        male
# 4      2009-10-01              2  Johannesburg  [2009-09-30]        male
# ...           ...            ...           ...           ...         ...
# 2028   2015-09-15              1       Belfast  [2007-06-29]        male
# 2029   2017-02-14              1       Colombo  [2017-02-10]      female
# 2030   2019-06-16              1        London  [2019-06-15]        male
# 2031   2015-11-23              1           NaN  [2006-08-06]        male
# 2032   2012-07-08              2       Jamaica  [2012-07-07]        male
#
#      info.match_type  info.match_type_number info.outcome.winner  ...
# 0                ODI                  4185.0             Ireland  ...  \
# 1                ODI                     NaN               India  ...
# 2                ODI                     NaN         West Indies  ...
# 3                ODI                     NaN            Pakistan  ...
# 4                ODI                     NaN               India  ...
# ...              ...                     ...                 ...  ...
# 2028             ODI                     NaN               India  ...
# 2029             ODI                     NaN               India  ...
# 2030             ODI                  4159.0           Australia  ...
# 2031             ODI                     NaN          Bangladesh  ...
# 2032             ODI                     NaN         West Indies  ...
#
#       info.supersubs.India  info.supersubs.New Zealand
# 0                      NaN                         NaN  \
# 1                      NaN                         NaN
# 2                      NaN                         NaN
# 3                      NaN                         NaN
# 4                      NaN                         NaN
# ...                    ...                         ...
# 2028                   NaN                         NaN
# 2029                   NaN                         NaN
# 2030                   NaN                         NaN
# 2031                   NaN                         NaN
# 2032                   NaN                         NaN
#
#      info.supersubs.West Indies info.supersubs.Africa XI
# 0                           NaN                      NaN  \
# 1                           NaN                      NaN
# 2                           NaN                      NaN
# 3                           NaN                      NaN
# 4                           NaN                      NaN
# ...                         ...                      ...
# 2028                        NaN                      NaN
# 2029                        NaN                      NaN
# 2030                        NaN                      NaN
# 2031                        NaN                      NaN
# 2032                        NaN                      NaN
#
#      info.supersubs.Asia XI info.supersubs.ICC World XI
# 0                       NaN                         NaN  \
# 1                       NaN                         NaN
# 2                       NaN                         NaN
# 3                       NaN                         NaN
# 4                       NaN                         NaN
# ...                     ...                         ...
# 2028                    NaN                         NaN
# 2029                    NaN                         NaN
# 2030                    NaN                         NaN
# 2031                    NaN                         NaN
# 2032                    NaN                         NaN
#
#      info.supersubs.Zimbabwe  info.supersubs.England  info.supersubs.Pakistan
# 0                        NaN                     NaN                      NaN  \
# 1                        NaN                     NaN                      NaN
# 2                        NaN                     NaN                      NaN
# 3                        NaN                     NaN                      NaN
# 4                        NaN                     NaN                      NaN
# ...                      ...                     ...                      ...
# 2028                     NaN                     NaN                      NaN
# 2029                     NaN                     NaN                      NaN
# 2030                     NaN                     NaN                      NaN
# 2031                     NaN                     NaN                      NaN
# 2032                     NaN                     NaN                      NaN
#
#      info.outcome.eliminator
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ...                      ...
# 2028                     NaN
# 2029                     NaN
# 2030                     NaN
# 2031                     NaN
# 2032                     NaN
#
# [2033 rows x 37 columns]

# %%
df = final_df.copy()

# %%
df.info()

# 0,4,5,6,7,9,11,12,13,14,15,16,17,19
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2033 entries, 0 to 2032
# Data columns (total 37 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   innings                      2033 non-null   object
#  1   meta.data_version            2033 non-null   float64
#  2   meta.created                 2033 non-null   object
#  3   meta.revision                2033 non-null   int64
#  4   info.city                    1698 non-null   object
#  5   info.dates                   2033 non-null   object
#  6   info.gender                  2033 non-null   object
#  7   info.match_type              2033 non-null   object
#  8   info.match_type_number       515 non-null    float64
#  9   info.outcome.winner          1938 non-null   object
#  10  info.outcome.by.runs         955 non-null    float64
#  11  info.overs                   2033 non-null   int64
#  12  info.teams                   2033 non-null   object
#  13  info.toss.decision           2033 non-null   object
#  14  info.toss.winner             2033 non-null   object
#  15  info.umpires                 2033 non-null   object
#  16  info.venue                   2033 non-null   object
#  17  match_id                     2033 non-null   int64
#  18  info.outcome.by.wickets      983 non-null    float64
#  19  info.player_of_match         1882 non-null   object
#  20  info.neutral_venue           358 non-null    float64
#  21  info.outcome.method          183 non-null    object
#  22  info.supersubs.Australia     10 non-null     object
#  23  info.supersubs.South Africa  12 non-null     object
#  24  info.outcome.result          95 non-null     object
#  25  info.supersubs.Sri Lanka     19 non-null     object
#  26  info.supersubs.Bangladesh    4 non-null      object
#  27  info.supersubs.India         12 non-null     object
#  28  info.supersubs.New Zealand   14 non-null     object
#  29  info.supersubs.West Indies   5 non-null      object
#  30  info.supersubs.Africa XI     2 non-null      object
#  31  info.supersubs.Asia XI       2 non-null      object
#  32  info.supersubs.ICC World XI  2 non-null      object
#  33  info.supersubs.Zimbabwe      3 non-null      object
#  34  info.supersubs.England       4 non-null      object
#  35  info.supersubs.Pakistan      6 non-null      object
#  36  info.outcome.eliminator      2 non-null      object
# dtypes: float64(5), int64(3), object(29)
# memory usage: 587.8+ KB

# %%
df.iloc[:2,0:18]

#1,2,3,5,7,8,17,21,22,23,24,...35
# Out:
#                                              innings  meta.data_version
# 0  [{'1st innings': {'team': 'Ireland', 'deliveri...                0.9  \
# 1  [{'1st innings': {'team': 'Bangladesh', 'deliv...                0.9
#
#   meta.created  meta.revision info.city    info.dates info.gender
# 0   2019-07-22              1   Belfast  [2019-07-04]        male  \
# 1   2010-01-08              2    Mirpur  [2010-01-07]        male
#
#   info.match_type  info.match_type_number info.outcome.winner
# 0             ODI                  4185.0             Ireland  \
# 1             ODI                     NaN               India
#
#    info.outcome.by.runs  info.overs           info.teams info.toss.decision
# 0                   5.0          50  [Ireland, Zimbabwe]              field  \
# 1                   NaN          50  [Bangladesh, India]                bat
#
#   info.toss.winner              info.umpires
# 0         Zimbabwe       [R Black, S George]  \
# 1       Bangladesh  [Enamul Haque, IJ Gould]
#
#                              info.venue  match_id
# 0  Civil Service Cricket Club, Stormont         1
# 1         Shere Bangla National Stadium         2

# %%
df.iloc[:2,18:]
# Out:
#    info.outcome.by.wickets info.player_of_match  info.neutral_venue
# 0                      NaN                  NaN                 NaN  \
# 1                      6.0           [MS Dhoni]                 NaN
#
#   info.outcome.method info.supersubs.Australia info.supersubs.South Africa
# 0                 NaN                      NaN                         NaN  \
# 1                 NaN                      NaN                         NaN
#
#   info.outcome.result info.supersubs.Sri Lanka info.supersubs.Bangladesh
# 0                 NaN                      NaN                       NaN  \
# 1                 NaN                      NaN                       NaN
#
#   info.supersubs.India info.supersubs.New Zealand info.supersubs.West Indies
# 0                  NaN                        NaN                        NaN  \
# 1                  NaN                        NaN                        NaN
#
#   info.supersubs.Africa XI info.supersubs.Asia XI info.supersubs.ICC World XI
# 0                      NaN                    NaN                         NaN  \
# 1                      NaN                    NaN                         NaN
#
#   info.supersubs.Zimbabwe info.supersubs.England info.supersubs.Pakistan
# 0                     NaN                    NaN                     NaN  \
# 1                     NaN                    NaN                     NaN
#
#   info.outcome.eliminator
# 0                     NaN
# 1                     NaN

# %%
df=df.iloc[:,[0,4,5,6,7,9,11,12,13,14,15,16,17,19]]

# %%
df.head(2)
# Out:
#                                              innings info.city    info.dates
# 0  [{'1st innings': {'team': 'Ireland', 'deliveri...   Belfast  [2019-07-04]  \
# 1  [{'1st innings': {'team': 'Bangladesh', 'deliv...    Mirpur  [2010-01-07]
#
#   info.gender info.match_type info.outcome.winner  info.overs
# 0        male             ODI             Ireland          50  \
# 1        male             ODI               India          50
#
#             info.teams info.toss.decision info.toss.winner
# 0  [Ireland, Zimbabwe]              field         Zimbabwe  \
# 1  [Bangladesh, India]                bat       Bangladesh
#
#                info.umpires                            info.venue  match_id
# 0       [R Black, S George]  Civil Service Cricket Club, Stormont         1  \
# 1  [Enamul Haque, IJ Gould]         Shere Bangla National Stadium         2
#
#   info.player_of_match
# 0                  NaN
# 1           [MS Dhoni]

# %%
df.shape
# Out:
# (2033, 14)

# %%
df['info.gender'].value_counts()
# Out:
# info.gender
# male      1799
# female     234
# Name: count, dtype: int64

# %%
plt.pie(df['info.gender'].value_counts(),labels=['male','female'],autopct="%.2f")
plt.show()

# %%
df=df[df['info.gender']=="male"]

# %%
df['info.gender'].value_counts()
# Out:
# info.gender
# male    1799
# Name: count, dtype: int64

# %%
df['info.match_type'].value_counts()
# Out:
# info.match_type
# ODI    1799
# Name: count, dtype: int64

# %%
df.drop(columns=['info.match_type'],inplace=True)

# %%
df.head(2)
# Out:
#                                              innings info.city    info.dates
# 0  [{'1st innings': {'team': 'Ireland', 'deliveri...   Belfast  [2019-07-04]  \
# 1  [{'1st innings': {'team': 'Bangladesh', 'deliv...    Mirpur  [2010-01-07]
#
#   info.gender info.outcome.winner  info.overs           info.teams
# 0        male             Ireland          50  [Ireland, Zimbabwe]  \
# 1        male               India          50  [Bangladesh, India]
#
#   info.toss.decision info.toss.winner              info.umpires
# 0              field         Zimbabwe       [R Black, S George]  \
# 1                bat       Bangladesh  [Enamul Haque, IJ Gould]
#
#                              info.venue  match_id info.player_of_match
# 0  Civil Service Cricket Club, Stormont         1                  NaN
# 1         Shere Bangla National Stadium         2           [MS Dhoni]

# %%
df['info.overs'].value_counts()
df.drop(columns=['info.overs'],inplace=True)

# %%
df['info.city'].value_counts()
# Out:
# info.city
# Mirpur                88
# Colombo               64
# London                63
# Bulawayo              42
# Abu Dhabi             40
#                       ..
# Glasgow                1
# Jamshedpur             1
# Adelaide               1
# Thiruvananthapuram     1
# Bready                 1
# Name: count, Length: 127, dtype: int64

# %%
df['info.venue'].value_counts()
# Out:
# info.venue
# Shere Bangla National Stadium                                      88
# Harare Sports Club                                                 73
# R Premadasa Stadium                                                47
# Queens Sports Club                                                 42
# Sheikh Zayed Stadium                                               40
#                                                                    ..
# Indian Petrochemicals Corporation Limited Sports Complex Ground     1
# Ruaraka Sports Club Ground                                          1
# Sharjah Cricket Association Stadium                                 1
# Greenfield International Stadium                                    1
# Wanderers Cricket Ground                                            1
# Name: count, Length: 179, dtype: int64

# %%
import pickle
pickle.dump(final_df,open('dataset_level1.pkl','wb'))

# %%
df = pickle.load(open('dataset_level1.pkl','rb'))

# %%
df.iloc[1]['innings'][1]['2nd innings']['deliveries']
# Out:
# [{0.1: {'batsman': 'G Gambhir',
#    'bowler': 'Syed Rasel',
#    'non_striker': 'V Sehwag',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {0.2: {'batsman': 'G Gambhir',
#    'bowler': 'Syed Rasel',
#    'non_striker': 'V Sehwag',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {0.3: {'batsman': 'G Gambhir',
#    'bowler': 'Syed Rasel',
#    'non_striker': 'V Sehwag',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {0.4: {'batsman': 'G Gambhir',
#    'bowler': 'Syed Rasel',
#    'non_striker': 'V Sehwag',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {0.5: {'batsman': 'G Gambhir',
#    'bowler': 'Syed Rasel',
#    'non_striker': 'V Sehwag',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {0.6: {'batsman': 'G Gambhir',
#    'bowler': 'Syed Rasel',
#    'extras': {'noballs': 1},
#    'non_striker': 'V Sehwag',
#    'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#  {0.7: {'batsman': 'G Gambhir',
#    'bowler': 'Syed Rasel',
#    'extras': {'noballs': 1},
#    'non_striker': 'V Sehwag',
#    'runs': {'batsman': 1, 'extras': 1, 'total': 2}}},
#  {0.8: {'batsman': 'V Sehwag',
#    'bowler': 'Syed Rasel',
#    'non_striker': 'G Gambhir',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {1.1: {'batsman': 'G Gambhir',
#    'bowler': 'Abdur Razzak',
#    'non_striker': 'V Sehwag',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {1.2: {'batsman': 'V Sehwag',
#    'bowler': 'Abdur Razzak',
#    'non_striker': 'G Gambhir',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {1.3: {'batsman': 'V Sehwag',
#    'bowler': 'Abdur Razzak',
#    'non_striker': 'G Gambhir',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {1.4: {'batsman': 'G Gambhir',
#    'bowler': 'Abdur Razzak',
#    'extras': {'wides': 1},
#    'non_striker': 'V Sehwag',
#    'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#  {1.5: {'batsman': 'G Gambhir',
#    'bowler': 'Abdur Razzak',
#    'non_striker': 'V Sehwag',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {1.6: {'batsman': 'G Gambhir',
#    'bowler': 'Abdur Razzak',
#    'non_striker': 'V Sehwag',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {1.7: {'batsman': 'V Sehwag',
#    'bowler': 'Abdur Razzak',
#    'non_striker': 'G Gambhir',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {2.1: {'batsman': 'V Sehwag',
#    'bowler': 'Syed Rasel',
#    'non_striker': 'G Gambhir',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {2.2: {'batsman': 'V Sehwag',
#    'bowler': 'Syed Rasel',
#    'non_striker': 'G Gambhir',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {2.3: {'batsman': 'V Sehwag',
#    'bowler': 'Syed Rasel',
#    'extras': {'wides': 1},
#    'non_striker': 'G Gambhir',
#    'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#  {2.4: {'batsman': 'V Sehwag',
#    'bowler': 'Syed Rasel',
#    'non_striker': 'G Gambhir',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {2.5: {'batsman': 'G Gambhir',
#    'bowler': 'Syed Rasel',
#    'non_striker': 'V Sehwag',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {2.6: {'batsman': 'G Gambhir',
#    'bowler': 'Syed Rasel',
#    'non_striker': 'V Sehwag',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {2.7: {'batsman': 'G Gambhir',
#    'bowler': 'Syed Rasel',
#    'non_striker': 'V Sehwag',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {3.1: {'batsman': 'V Sehwag',
#    'bowler': 'Abdur Razzak',
#    'non_striker': 'G Gambhir',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#    'wicket': {'fielders': ['Abdur Razzak'],
#     'kind': 'run out',
#     'player_out': 'V Sehwag'}}},
#  {3.2: {'batsman': 'G Gambhir',
#    'bowler': 'Abdur Razzak',
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {3.3: {'batsman': 'G Gambhir',
#    'bowler': 'Abdur Razzak',
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {3.4: {'batsman': 'G Gambhir',
#    'bowler': 'Abdur Razzak',
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {3.5: {'batsman': 'V Kohli',
#    'bowler': 'Abdur Razzak',
#    'extras': {'legbyes': 1},
#    'non_striker': 'G Gambhir',
#    'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#  {3.6: {'batsman': 'G Gambhir',
#    'bowler': 'Abdur Razzak',
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {4.1: {'batsman': 'V Kohli',
#    'bowler': 'Syed Rasel',
#    'non_striker': 'G Gambhir',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {4.2: {'batsman': 'V Kohli',
#    'bowler': 'Syed Rasel',
#    'non_striker': 'G Gambhir',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {4.3: {'batsman': 'V Kohli',
#    'bowler': 'Syed Rasel',
#    'non_striker': 'G Gambhir',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {4.4: {'batsman': 'V Kohli',
#    'bowler': 'Syed Rasel',
#    'non_striker': 'G Gambhir',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {4.5: {'batsman': 'V Kohli',
#    'bowler': 'Syed Rasel',
#    'non_striker': 'G Gambhir',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {4.6: {'batsman': 'G Gambhir',
#    'bowler': 'Syed Rasel',
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {5.1: {'batsman': 'V Kohli',
#    'bowler': 'Abdur Razzak',
#    'non_striker': 'G Gambhir',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {5.2: {'batsman': 'V Kohli',
#    'bowler': 'Abdur Razzak',
#    'non_striker': 'G Gambhir',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {5.3: {'batsman': 'G Gambhir',
#    'bowler': 'Abdur Razzak',
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {5.4: {'batsman': 'G Gambhir',
#    'bowler': 'Abdur Razzak',
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {5.5: {'batsman': 'V Kohli',
#    'bowler': 'Abdur Razzak',
#    'non_striker': 'G Gambhir',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {5.6: {'batsman': 'V Kohli',
#    'bowler': 'Abdur Razzak',
#    'non_striker': 'G Gambhir',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {6.1: {'batsman': 'V Kohli',
#    'bowler': 'Syed Rasel',
#    'non_striker': 'G Gambhir',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {6.2: {'batsman': 'V Kohli',
#    'bowler': 'Syed Rasel',
#    'non_striker': 'G Gambhir',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {6.3: {'batsman': 'G Gambhir',
#    'bowler': 'Syed Rasel',
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {6.4: {'batsman': 'V Kohli',
#    'bowler': 'Syed Rasel',
#    'extras': {'wides': 1},
#    'non_striker': 'G Gambhir',
#    'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#  {6.5: {'batsman': 'V Kohli',
#    'bowler': 'Syed Rasel',
#    'non_striker': 'G Gambhir',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {6.6: {'batsman': 'V Kohli',
#    'bowler': 'Syed Rasel',
#    'non_striker': 'G Gambhir',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {6.7: {'batsman': 'V Kohli',
#    'bowler': 'Syed Rasel',
#    'non_striker': 'G Gambhir',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {7.1: {'batsman': 'G Gambhir',
#    'bowler': 'Rubel Hossain',
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {7.2: {'batsman': 'G Gambhir',
#    'bowler': 'Rubel Hossain',
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {7.3: {'batsman': 'G Gambhir',
#    'bowler': 'Rubel Hossain',
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#    'wicket': {'kind': 'bowled', 'player_out': 'G Gambhir'}}},
#  {7.4: {'batsman': 'Yuvraj Singh',
#    'bowler': 'Rubel Hossain',
#    'extras': {'wides': 1},
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#  {7.5: {'batsman': 'Yuvraj Singh',
#    'bowler': 'Rubel Hossain',
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {7.6: {'batsman': 'Yuvraj Singh',
#    'bowler': 'Rubel Hossain',
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {7.7: {'batsman': 'Yuvraj Singh',
#    'bowler': 'Rubel Hossain',
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {8.1: {'batsman': 'Yuvraj Singh',
#    'bowler': 'Syed Rasel',
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#    'wicket': {'kind': 'bowled', 'player_out': 'Yuvraj Singh'}}},
#  {8.2: {'batsman': 'MS Dhoni',
#    'bowler': 'Syed Rasel',
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {8.3: {'batsman': 'MS Dhoni',
#    'bowler': 'Syed Rasel',
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {8.4: {'batsman': 'MS Dhoni',
#    'bowler': 'Syed Rasel',
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {8.5: {'batsman': 'MS Dhoni',
#    'bowler': 'Syed Rasel',
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {8.6: {'batsman': 'MS Dhoni',
#    'bowler': 'Syed Rasel',
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {9.1: {'batsman': 'MS Dhoni',
#    'bowler': 'Rubel Hossain',
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {9.2: {'batsman': 'MS Dhoni',
#    'bowler': 'Rubel Hossain',
#    'extras': {'noballs': 1},
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#  {9.3: {'batsman': 'MS Dhoni',
#    'bowler': 'Rubel Hossain',
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {9.4: {'batsman': 'V Kohli',
#    'bowler': 'Rubel Hossain',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {9.5: {'batsman': 'V Kohli',
#    'bowler': 'Rubel Hossain',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {9.6: {'batsman': 'V Kohli',
#    'bowler': 'Rubel Hossain',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {9.7: {'batsman': 'V Kohli',
#    'bowler': 'Rubel Hossain',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {10.1: {'batsman': 'MS Dhoni',
#    'bowler': 'Syed Rasel',
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {10.2: {'batsman': 'MS Dhoni',
#    'bowler': 'Syed Rasel',
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {10.3: {'batsman': 'MS Dhoni',
#    'bowler': 'Syed Rasel',
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {10.4: {'batsman': 'MS Dhoni',
#    'bowler': 'Syed Rasel',
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {10.5: {'batsman': 'MS Dhoni',
#    'bowler': 'Syed Rasel',
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {10.6: {'batsman': 'MS Dhoni',
#    'bowler': 'Syed Rasel',
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {11.1: {'batsman': 'V Kohli',
#    'bowler': 'Rubel Hossain',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {11.2: {'batsman': 'V Kohli',
#    'bowler': 'Rubel Hossain',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {11.3: {'batsman': 'V Kohli',
#    'bowler': 'Rubel Hossain',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {11.4: {'batsman': 'V Kohli',
#    'bowler': 'Rubel Hossain',
#    'extras': {'wides': 1},
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#  {11.5: {'batsman': 'V Kohli',
#    'bowler': 'Rubel Hossain',
#    'extras': {'legbyes': 2},
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 0, 'extras': 2, 'total': 2}}},
#  {11.6: {'batsman': 'V Kohli',
#    'bowler': 'Rubel Hossain',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {11.7: {'batsman': 'MS Dhoni',
#    'bowler': 'Rubel Hossain',
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {12.1: {'batsman': 'V Kohli',
#    'bowler': 'Syed Rasel',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {12.2: {'batsman': 'V Kohli',
#    'bowler': 'Syed Rasel',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {12.3: {'batsman': 'V Kohli',
#    'bowler': 'Syed Rasel',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {12.4: {'batsman': 'V Kohli',
#    'bowler': 'Syed Rasel',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {12.5: {'batsman': 'V Kohli',
#    'bowler': 'Syed Rasel',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {12.6: {'batsman': 'V Kohli',
#    'bowler': 'Syed Rasel',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {13.1: {'batsman': 'MS Dhoni',
#    'bowler': 'Rubel Hossain',
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {13.2: {'batsman': 'V Kohli',
#    'bowler': 'Rubel Hossain',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {13.3: {'batsman': 'MS Dhoni',
#    'bowler': 'Rubel Hossain',
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {13.4: {'batsman': 'MS Dhoni',
#    'bowler': 'Rubel Hossain',
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {13.5: {'batsman': 'MS Dhoni',
#    'bowler': 'Rubel Hossain',
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {13.6: {'batsman': 'MS Dhoni',
#    'bowler': 'Rubel Hossain',
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {14.1: {'batsman': 'V Kohli',
#    'bowler': 'Shakib Al Hasan',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {14.2: {'batsman': 'V Kohli',
#    'bowler': 'Shakib Al Hasan',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {14.3: {'batsman': 'V Kohli',
#    'bowler': 'Shakib Al Hasan',
#    'extras': {'legbyes': 1},
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#  {14.4: {'batsman': 'MS Dhoni',
#    'bowler': 'Shakib Al Hasan',
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {14.5: {'batsman': 'MS Dhoni',
#    'bowler': 'Shakib Al Hasan',
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {14.6: {'batsman': 'V Kohli',
#    'bowler': 'Shakib Al Hasan',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {15.1: {'batsman': 'V Kohli',
#    'bowler': 'Abdur Razzak',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {15.2: {'batsman': 'MS Dhoni',
#    'bowler': 'Abdur Razzak',
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {15.3: {'batsman': 'MS Dhoni',
#    'bowler': 'Abdur Razzak',
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {15.4: {'batsman': 'MS Dhoni',
#    'bowler': 'Abdur Razzak',
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {15.5: {'batsman': 'V Kohli',
#    'bowler': 'Abdur Razzak',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {15.6: {'batsman': 'MS Dhoni',
#    'bowler': 'Abdur Razzak',
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {16.1: {'batsman': 'V Kohli',
#    'bowler': 'Shakib Al Hasan',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {16.2: {'batsman': 'MS Dhoni',
#    'bowler': 'Shakib Al Hasan',
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {16.3: {'batsman': 'MS Dhoni',
#    'bowler': 'Shakib Al Hasan',
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {16.4: {'batsman': 'MS Dhoni',
#    'bowler': 'Shakib Al Hasan',
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {16.5: {'batsman': 'V Kohli',
#    'bowler': 'Shakib Al Hasan',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {16.6: {'batsman': 'MS Dhoni',
#    'bowler': 'Shakib Al Hasan',
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {17.1: {'batsman': 'V Kohli',
#    'bowler': 'Naeem Islam',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {17.2: {'batsman': 'MS Dhoni',
#    'bowler': 'Naeem Islam',
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {17.3: {'batsman': 'V Kohli',
#    'bowler': 'Naeem Islam',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {17.4: {'batsman': 'V Kohli',
#    'bowler': 'Naeem Islam',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {17.5: {'batsman': 'MS Dhoni',
#    'bowler': 'Naeem Islam',
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 3, 'extras': 0, 'total': 3}}},
#  {17.6: {'batsman': 'V Kohli',
#    'bowler': 'Naeem Islam',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {18.1: {'batsman': 'V Kohli',
#    'bowler': 'Shakib Al Hasan',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {18.2: {'batsman': 'V Kohli',
#    'bowler': 'Shakib Al Hasan',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {18.3: {'batsman': 'MS Dhoni',
#    'bowler': 'Shakib Al Hasan',
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {18.4: {'batsman': 'V Kohli',
#    'bowler': 'Shakib Al Hasan',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {18.5: {'batsman': 'V Kohli',
#    'bowler': 'Shakib Al Hasan',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {18.6: {'batsman': 'V Kohli',
#    'bowler': 'Shakib Al Hasan',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {19.1: {'batsman': 'V Kohli',
#    'bowler': 'Naeem Islam',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {19.2: {'batsman': 'MS Dhoni',
#    'bowler': 'Naeem Islam',
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {19.3: {'batsman': 'V Kohli',
#    'bowler': 'Naeem Islam',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {19.4: {'batsman': 'MS Dhoni',
#    'bowler': 'Naeem Islam',
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {19.5: {'batsman': 'V Kohli',
#    'bowler': 'Naeem Islam',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {19.6: {'batsman': 'V Kohli',
#    'bowler': 'Naeem Islam',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {20.1: {'batsman': 'V Kohli',
#    'bowler': 'Shakib Al Hasan',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {20.2: {'batsman': 'V Kohli',
#    'bowler': 'Shakib Al Hasan',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {20.3: {'batsman': 'V Kohli',
#    'bowler': 'Shakib Al Hasan',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {20.4: {'batsman': 'MS Dhoni',
#    'bowler': 'Shakib Al Hasan',
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {20.5: {'batsman': 'V Kohli',
#    'bowler': 'Shakib Al Hasan',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {20.6: {'batsman': 'MS Dhoni',
#    'bowler': 'Shakib Al Hasan',
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {21.1: {'batsman': 'V Kohli',
#    'bowler': 'Mahmudullah',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {21.2: {'batsman': 'V Kohli',
#    'bowler': 'Mahmudullah',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {21.3: {'batsman': 'MS Dhoni',
#    'bowler': 'Mahmudullah',
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {21.4: {'batsman': 'MS Dhoni',
#    'bowler': 'Mahmudullah',
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {21.5: {'batsman': 'V Kohli',
#    'bowler': 'Mahmudullah',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {21.6: {'batsman': 'MS Dhoni',
#    'bowler': 'Mahmudullah',
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {22.1: {'batsman': 'V Kohli',
#    'bowler': 'Shakib Al Hasan',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {22.2: {'batsman': 'V Kohli',
#    'bowler': 'Shakib Al Hasan',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {22.3: {'batsman': 'V Kohli',
#    'bowler': 'Shakib Al Hasan',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {22.4: {'batsman': 'V Kohli',
#    'bowler': 'Shakib Al Hasan',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {22.5: {'batsman': 'MS Dhoni',
#    'bowler': 'Shakib Al Hasan',
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {22.6: {'batsman': 'V Kohli',
#    'bowler': 'Shakib Al Hasan',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {23.1: {'batsman': 'V Kohli',
#    'bowler': 'Mahmudullah',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {23.2: {'batsman': 'V Kohli',
#    'bowler': 'Mahmudullah',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {23.3: {'batsman': 'V Kohli',
#    'bowler': 'Mahmudullah',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {23.4: {'batsman': 'V Kohli',
#    'bowler': 'Mahmudullah',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {23.5: {'batsman': 'V Kohli',
#    'bowler': 'Mahmudullah',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {23.6: {'batsman': 'V Kohli',
#    'bowler': 'Mahmudullah',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {24.1: {'batsman': 'MS Dhoni',
#    'bowler': 'Shakib Al Hasan',
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {24.2: {'batsman': 'V Kohli',
#    'bowler': 'Shakib Al Hasan',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {24.3: {'batsman': 'MS Dhoni',
#    'bowler': 'Shakib Al Hasan',
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {24.4: {'batsman': 'MS Dhoni',
#    'bowler': 'Shakib Al Hasan',
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {24.5: {'batsman': 'V Kohli',
#    'bowler': 'Shakib Al Hasan',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {24.6: {'batsman': 'V Kohli',
#    'bowler': 'Shakib Al Hasan',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {25.1: {'batsman': 'MS Dhoni',
#    'bowler': 'Mahmudullah',
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {25.2: {'batsman': 'MS Dhoni',
#    'bowler': 'Mahmudullah',
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {25.3: {'batsman': 'V Kohli',
#    'bowler': 'Mahmudullah',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {25.4: {'batsman': 'V Kohli',
#    'bowler': 'Mahmudullah',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {25.5: {'batsman': 'MS Dhoni',
#    'bowler': 'Mahmudullah',
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {25.6: {'batsman': 'V Kohli',
#    'bowler': 'Mahmudullah',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {26.1: {'batsman': 'V Kohli',
#    'bowler': 'Rubel Hossain',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {26.2: {'batsman': 'V Kohli',
#    'bowler': 'Rubel Hossain',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {26.3: {'batsman': 'MS Dhoni',
#    'bowler': 'Rubel Hossain',
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {26.4: {'batsman': 'MS Dhoni',
#    'bowler': 'Rubel Hossain',
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {26.5: {'batsman': 'MS Dhoni',
#    'bowler': 'Rubel Hossain',
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {26.6: {'batsman': 'MS Dhoni',
#    'bowler': 'Rubel Hossain',
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {27.1: {'batsman': 'MS Dhoni',
#    'bowler': 'Mahmudullah',
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {27.2: {'batsman': 'MS Dhoni',
#    'bowler': 'Mahmudullah',
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {27.3: {'batsman': 'V Kohli',
#    'bowler': 'Mahmudullah',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {27.4: {'batsman': 'MS Dhoni',
#    'bowler': 'Mahmudullah',
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {27.5: {'batsman': 'V Kohli',
#    'bowler': 'Mahmudullah',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {27.6: {'batsman': 'MS Dhoni',
#    'bowler': 'Mahmudullah',
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {28.1: {'batsman': 'MS Dhoni',
#    'bowler': 'Rubel Hossain',
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {28.2: {'batsman': 'MS Dhoni',
#    'bowler': 'Rubel Hossain',
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {28.3: {'batsman': 'V Kohli',
#    'bowler': 'Rubel Hossain',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {28.4: {'batsman': 'V Kohli',
#    'bowler': 'Rubel Hossain',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {28.5: {'batsman': 'MS Dhoni',
#    'bowler': 'Rubel Hossain',
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {28.6: {'batsman': 'MS Dhoni',
#    'bowler': 'Rubel Hossain',
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {29.1: {'batsman': 'MS Dhoni',
#    'bowler': 'Abdur Razzak',
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {29.2: {'batsman': 'MS Dhoni',
#    'bowler': 'Abdur Razzak',
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {29.3: {'batsman': 'V Kohli',
#    'bowler': 'Abdur Razzak',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {29.4: {'batsman': 'V Kohli',
#    'bowler': 'Abdur Razzak',
#    'extras': {'wides': 2},
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 0, 'extras': 2, 'total': 2}}},
#  {29.5: {'batsman': 'MS Dhoni',
#    'bowler': 'Abdur Razzak',
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {29.6: {'batsman': 'V Kohli',
#    'bowler': 'Abdur Razzak',
#    'extras': {'wides': 1},
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#  {29.7: {'batsman': 'V Kohli',
#    'bowler': 'Abdur Razzak',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {29.8: {'batsman': 'V Kohli',
#    'bowler': 'Abdur Razzak',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {30.1: {'batsman': 'MS Dhoni',
#    'bowler': 'Mahmudullah',
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {30.2: {'batsman': 'V Kohli',
#    'bowler': 'Mahmudullah',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {30.3: {'batsman': 'MS Dhoni',
#    'bowler': 'Mahmudullah',
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {30.4: {'batsman': 'MS Dhoni',
#    'bowler': 'Mahmudullah',
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {30.5: {'batsman': 'V Kohli',
#    'bowler': 'Mahmudullah',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {30.6: {'batsman': 'MS Dhoni',
#    'bowler': 'Mahmudullah',
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {31.1: {'batsman': 'MS Dhoni',
#    'bowler': 'Mohammad Ashraful',
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {31.2: {'batsman': 'V Kohli',
#    'bowler': 'Mohammad Ashraful',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {31.3: {'batsman': 'MS Dhoni',
#    'bowler': 'Mohammad Ashraful',
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {31.4: {'batsman': 'V Kohli',
#    'bowler': 'Mohammad Ashraful',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {31.5: {'batsman': 'V Kohli',
#    'bowler': 'Mohammad Ashraful',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {31.6: {'batsman': 'MS Dhoni',
#    'bowler': 'Mohammad Ashraful',
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {32.1: {'batsman': 'V Kohli',
#    'bowler': 'Shakib Al Hasan',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {32.2: {'batsman': 'MS Dhoni',
#    'bowler': 'Shakib Al Hasan',
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {32.3: {'batsman': 'MS Dhoni',
#    'bowler': 'Shakib Al Hasan',
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {32.4: {'batsman': 'MS Dhoni',
#    'bowler': 'Shakib Al Hasan',
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {32.5: {'batsman': 'MS Dhoni',
#    'bowler': 'Shakib Al Hasan',
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {32.6: {'batsman': 'V Kohli',
#    'bowler': 'Shakib Al Hasan',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {33.1: {'batsman': 'V Kohli',
#    'bowler': 'Abdur Razzak',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {33.2: {'batsman': 'V Kohli',
#    'bowler': 'Abdur Razzak',
#    'extras': {'wides': 1},
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#  {33.3: {'batsman': 'V Kohli',
#    'bowler': 'Abdur Razzak',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {33.4: {'batsman': 'V Kohli',
#    'bowler': 'Abdur Razzak',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {33.5: {'batsman': 'MS Dhoni',
#    'bowler': 'Abdur Razzak',
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {33.6: {'batsman': 'V Kohli',
#    'bowler': 'Abdur Razzak',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {33.7: {'batsman': 'V Kohli',
#    'bowler': 'Abdur Razzak',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {34.1: {'batsman': 'V Kohli',
#    'bowler': 'Shakib Al Hasan',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {34.2: {'batsman': 'V Kohli',
#    'bowler': 'Shakib Al Hasan',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {34.3: {'batsman': 'V Kohli',
#    'bowler': 'Shakib Al Hasan',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {34.4: {'batsman': 'V Kohli',
#    'bowler': 'Shakib Al Hasan',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {34.5: {'batsman': 'MS Dhoni',
#    'bowler': 'Shakib Al Hasan',
#    'non_striker': 'V Kohli',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {34.6: {'batsman': 'V Kohli',
#    'bowler': 'Shakib Al Hasan',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0},
#    'wicket': {'kind': 'caught and bowled', 'player_out': 'V Kohli'}}},
#  {35.1: {'batsman': 'MS Dhoni',
#    'bowler': 'Abdur Razzak',
#    'non_striker': 'SK Raina',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {35.2: {'batsman': 'MS Dhoni',
#    'bowler': 'Abdur Razzak',
#    'non_striker': 'SK Raina',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {35.3: {'batsman': 'SK Raina',
#    'bowler': 'Abdur Razzak',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {35.4: {'batsman': 'MS Dhoni',
#    'bowler': 'Abdur Razzak',
#    'extras': {'legbyes': 2},
#    'non_striker': 'SK Raina',
#    'runs': {'batsman': 0, 'extras': 2, 'total': 2}}},
#  {35.5: {'batsman': 'MS Dhoni',
#    'bowler': 'Abdur Razzak',
#    'non_striker': 'SK Raina',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {35.6: {'batsman': 'MS Dhoni',
#    'bowler': 'Abdur Razzak',
#    'non_striker': 'SK Raina',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {36.1: {'batsman': 'MS Dhoni',
#    'bowler': 'Rubel Hossain',
#    'non_striker': 'SK Raina',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {36.2: {'batsman': 'SK Raina',
#    'bowler': 'Rubel Hossain',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {36.3: {'batsman': 'MS Dhoni',
#    'bowler': 'Rubel Hossain',
#    'non_striker': 'SK Raina',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {36.4: {'batsman': 'SK Raina',
#    'bowler': 'Rubel Hossain',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {36.5: {'batsman': 'SK Raina',
#    'bowler': 'Rubel Hossain',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {36.6: {'batsman': 'MS Dhoni',
#    'bowler': 'Rubel Hossain',
#    'non_striker': 'SK Raina',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {37.1: {'batsman': 'MS Dhoni',
#    'bowler': 'Mahmudullah',
#    'non_striker': 'SK Raina',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {37.2: {'batsman': 'MS Dhoni',
#    'bowler': 'Mahmudullah',
#    'extras': {'wides': 2},
#    'non_striker': 'SK Raina',
#    'runs': {'batsman': 0, 'extras': 2, 'total': 2}}},
#  {37.3: {'batsman': 'SK Raina',
#    'bowler': 'Mahmudullah',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {37.4: {'batsman': 'SK Raina',
#    'bowler': 'Mahmudullah',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {37.5: {'batsman': 'MS Dhoni',
#    'bowler': 'Mahmudullah',
#    'non_striker': 'SK Raina',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {37.6: {'batsman': 'SK Raina',
#    'bowler': 'Mahmudullah',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {37.7: {'batsman': 'SK Raina',
#    'bowler': 'Mahmudullah',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {38.1: {'batsman': 'MS Dhoni',
#    'bowler': 'Rubel Hossain',
#    'non_striker': 'SK Raina',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {38.2: {'batsman': 'SK Raina',
#    'bowler': 'Rubel Hossain',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {38.3: {'batsman': 'MS Dhoni',
#    'bowler': 'Rubel Hossain',
#    'non_striker': 'SK Raina',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {38.4: {'batsman': 'SK Raina',
#    'bowler': 'Rubel Hossain',
#    'extras': {'wides': 1},
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#  {38.5: {'batsman': 'SK Raina',
#    'bowler': 'Rubel Hossain',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {38.6: {'batsman': 'SK Raina',
#    'bowler': 'Rubel Hossain',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {38.7: {'batsman': 'SK Raina',
#    'bowler': 'Rubel Hossain',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {39.1: {'batsman': 'MS Dhoni',
#    'bowler': 'Shakib Al Hasan',
#    'non_striker': 'SK Raina',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {39.2: {'batsman': 'SK Raina',
#    'bowler': 'Shakib Al Hasan',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {39.3: {'batsman': 'SK Raina',
#    'bowler': 'Shakib Al Hasan',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {39.4: {'batsman': 'SK Raina',
#    'bowler': 'Shakib Al Hasan',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {39.5: {'batsman': 'SK Raina',
#    'bowler': 'Shakib Al Hasan',
#    'extras': {'wides': 1},
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 0, 'extras': 1, 'total': 1}}},
#  {39.6: {'batsman': 'SK Raina',
#    'bowler': 'Shakib Al Hasan',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {39.7: {'batsman': 'MS Dhoni',
#    'bowler': 'Shakib Al Hasan',
#    'non_striker': 'SK Raina',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {40.1: {'batsman': 'SK Raina',
#    'bowler': 'Mahmudullah',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {40.2: {'batsman': 'MS Dhoni',
#    'bowler': 'Mahmudullah',
#    'non_striker': 'SK Raina',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {40.3: {'batsman': 'SK Raina',
#    'bowler': 'Mahmudullah',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {40.4: {'batsman': 'SK Raina',
#    'bowler': 'Mahmudullah',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {40.5: {'batsman': 'MS Dhoni',
#    'bowler': 'Mahmudullah',
#    'non_striker': 'SK Raina',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {40.6: {'batsman': 'MS Dhoni',
#    'bowler': 'Mahmudullah',
#    'non_striker': 'SK Raina',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {41.1: {'batsman': 'SK Raina',
#    'bowler': 'Syed Rasel',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {41.2: {'batsman': 'SK Raina',
#    'bowler': 'Syed Rasel',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {41.3: {'batsman': 'SK Raina',
#    'bowler': 'Syed Rasel',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {41.4: {'batsman': 'MS Dhoni',
#    'bowler': 'Syed Rasel',
#    'non_striker': 'SK Raina',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {41.5: {'batsman': 'MS Dhoni',
#    'bowler': 'Syed Rasel',
#    'non_striker': 'SK Raina',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {41.6: {'batsman': 'SK Raina',
#    'bowler': 'Syed Rasel',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {42.1: {'batsman': 'SK Raina',
#    'bowler': 'Abdur Razzak',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {42.2: {'batsman': 'SK Raina',
#    'bowler': 'Abdur Razzak',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {42.3: {'batsman': 'SK Raina',
#    'bowler': 'Abdur Razzak',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {42.4: {'batsman': 'MS Dhoni',
#    'bowler': 'Abdur Razzak',
#    'non_striker': 'SK Raina',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {42.5: {'batsman': 'SK Raina',
#    'bowler': 'Abdur Razzak',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 3, 'extras': 0, 'total': 3}}},
#  {42.6: {'batsman': 'MS Dhoni',
#    'bowler': 'Abdur Razzak',
#    'non_striker': 'SK Raina',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {43.1: {'batsman': 'SK Raina',
#    'bowler': 'Syed Rasel',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {43.2: {'batsman': 'SK Raina',
#    'bowler': 'Syed Rasel',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {43.3: {'batsman': 'SK Raina',
#    'bowler': 'Syed Rasel',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {43.4: {'batsman': 'MS Dhoni',
#    'bowler': 'Syed Rasel',
#    'non_striker': 'SK Raina',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {43.5: {'batsman': 'SK Raina',
#    'bowler': 'Syed Rasel',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {43.6: {'batsman': 'SK Raina',
#    'bowler': 'Syed Rasel',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {44.1: {'batsman': 'MS Dhoni',
#    'bowler': 'Abdur Razzak',
#    'non_striker': 'SK Raina',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {44.2: {'batsman': 'MS Dhoni',
#    'bowler': 'Abdur Razzak',
#    'non_striker': 'SK Raina',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {44.3: {'batsman': 'MS Dhoni',
#    'bowler': 'Abdur Razzak',
#    'non_striker': 'SK Raina',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {44.4: {'batsman': 'MS Dhoni',
#    'bowler': 'Abdur Razzak',
#    'non_striker': 'SK Raina',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {44.5: {'batsman': 'SK Raina',
#    'bowler': 'Abdur Razzak',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {44.6: {'batsman': 'SK Raina',
#    'bowler': 'Abdur Razzak',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {45.1: {'batsman': 'MS Dhoni',
#    'bowler': 'Shakib Al Hasan',
#    'non_striker': 'SK Raina',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {45.2: {'batsman': 'MS Dhoni',
#    'bowler': 'Shakib Al Hasan',
#    'non_striker': 'SK Raina',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {45.3: {'batsman': 'SK Raina',
#    'bowler': 'Shakib Al Hasan',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {45.4: {'batsman': 'SK Raina',
#    'bowler': 'Shakib Al Hasan',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {45.5: {'batsman': 'SK Raina',
#    'bowler': 'Shakib Al Hasan',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {45.6: {'batsman': 'MS Dhoni',
#    'bowler': 'Shakib Al Hasan',
#    'non_striker': 'SK Raina',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {46.1: {'batsman': 'SK Raina',
#    'bowler': 'Rubel Hossain',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 0, 'extras': 0, 'total': 0}}},
#  {46.2: {'batsman': 'SK Raina',
#    'bowler': 'Rubel Hossain',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {46.3: {'batsman': 'MS Dhoni',
#    'bowler': 'Rubel Hossain',
#    'non_striker': 'SK Raina',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {46.4: {'batsman': 'SK Raina',
#    'bowler': 'Rubel Hossain',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {46.5: {'batsman': 'SK Raina',
#    'bowler': 'Rubel Hossain',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 2, 'extras': 0, 'total': 2}}},
#  {46.6: {'batsman': 'SK Raina',
#    'bowler': 'Rubel Hossain',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 6, 'extras': 0, 'total': 6}}},
#  {47.1: {'batsman': 'MS Dhoni',
#    'bowler': 'Syed Rasel',
#    'non_striker': 'SK Raina',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}},
#  {47.2: {'batsman': 'MS Dhoni',
#    'bowler': 'Syed Rasel',
#    'non_striker': 'SK Raina',
#    'runs': {'batsman': 1, 'extras': 0, 'total': 1}}},
#  {47.3: {'batsman': 'SK Raina',
#    'bowler': 'Syed Rasel',
#    'non_striker': 'MS Dhoni',
#    'runs': {'batsman': 4, 'extras': 0, 'total': 4}}}]

# %%
# df.iloc[0]['innings'][0]["1st innings"]['team'] batting team

df.iloc[0]['innings']
# Out:
# [{'1st innings': {'team': 'Ireland',
#    'deliveries': [{0.1: {'non_striker': 'JA McCollum',
#       'bowler': 'KM Jarvis',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'PR Stirling'}},
#     {0.2: {'non_striker': 'JA McCollum',
#       'bowler': 'KM Jarvis',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'PR Stirling'}},
#     {0.3: {'non_striker': 'JA McCollum',
#       'bowler': 'KM Jarvis',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'PR Stirling'}},
#     {0.4: {'non_striker': 'JA McCollum',
#       'bowler': 'KM Jarvis',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'PR Stirling'}},
#     {0.5: {'non_striker': 'JA McCollum',
#       'bowler': 'KM Jarvis',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'PR Stirling'}},
#     {0.6: {'non_striker': 'JA McCollum',
#       'bowler': 'KM Jarvis',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'PR Stirling'}},
#     {1.1: {'non_striker': 'PR Stirling',
#       'bowler': 'TL Chatara',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'JA McCollum'}},
#     {1.2: {'non_striker': 'PR Stirling',
#       'bowler': 'TL Chatara',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'JA McCollum'}},
#     {1.3: {'non_striker': 'PR Stirling',
#       'bowler': 'TL Chatara',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'JA McCollum'}},
#     {1.4: {'non_striker': 'PR Stirling',
#       'bowler': 'TL Chatara',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'JA McCollum'}},
#     {1.5: {'non_striker': 'JA McCollum',
#       'bowler': 'TL Chatara',
#       'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#       'batsman': 'PR Stirling'}},
#     {1.6: {'non_striker': 'JA McCollum',
#       'bowler': 'TL Chatara',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'PR Stirling'}},
#     {2.1: {'non_striker': 'PR Stirling',
#       'bowler': 'KM Jarvis',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'JA McCollum'}},
#     {2.2: {'non_striker': 'PR Stirling',
#       'bowler': 'KM Jarvis',
#       'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#       'batsman': 'JA McCollum'}},
#     {2.3: {'non_striker': 'PR Stirling',
#       'bowler': 'KM Jarvis',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'JA McCollum'}},
#     {2.4: {'non_striker': 'PR Stirling',
#       'bowler': 'KM Jarvis',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'JA McCollum'}},
#     {2.5: {'non_striker': 'PR Stirling',
#       'bowler': 'KM Jarvis',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'JA McCollum'}},
#     {2.6: {'non_striker': 'PR Stirling',
#       'bowler': 'KM Jarvis',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'JA McCollum'}},
#     {3.1: {'non_striker': 'JA McCollum',
#       'bowler': 'TL Chatara',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'PR Stirling'}},
#     {3.2: {'non_striker': 'JA McCollum',
#       'bowler': 'TL Chatara',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'PR Stirling'}},
#     {3.3: {'non_striker': 'JA McCollum',
#       'bowler': 'TL Chatara',
#       'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#       'batsman': 'PR Stirling'}},
#     {3.4: {'non_striker': 'JA McCollum',
#       'bowler': 'TL Chatara',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'PR Stirling'}},
#     {3.5: {'non_striker': 'JA McCollum',
#       'bowler': 'TL Chatara',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'PR Stirling'}},
#     {3.6: {'non_striker': 'JA McCollum',
#       'bowler': 'TL Chatara',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'PR Stirling'}},
#     {4.1: {'non_striker': 'PR Stirling',
#       'bowler': 'KM Jarvis',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'JA McCollum'}},
#     {4.2: {'non_striker': 'PR Stirling',
#       'bowler': 'KM Jarvis',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'JA McCollum'}},
#     {4.3: {'non_striker': 'PR Stirling',
#       'bowler': 'KM Jarvis',
#       'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#       'batsman': 'JA McCollum'}},
#     {4.4: {'non_striker': 'PR Stirling',
#       'bowler': 'KM Jarvis',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'JA McCollum'}},
#     {4.5: {'non_striker': 'PR Stirling',
#       'bowler': 'KM Jarvis',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'JA McCollum'}},
#     {4.6: {'non_striker': 'PR Stirling',
#       'bowler': 'KM Jarvis',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'JA McCollum'}},
#     {5.1: {'non_striker': 'JA McCollum',
#       'bowler': 'TL Chatara',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'PR Stirling'}},
#     {5.2: {'non_striker': 'JA McCollum',
#       'bowler': 'TL Chatara',
#       'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#       'batsman': 'PR Stirling'}},
#     {5.3: {'non_striker': 'JA McCollum',
#       'bowler': 'TL Chatara',
#       'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#       'batsman': 'PR Stirling'}},
#     {5.4: {'non_striker': 'JA McCollum',
#       'bowler': 'TL Chatara',
#       'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#       'batsman': 'PR Stirling'}},
#     {5.5: {'non_striker': 'JA McCollum',
#       'bowler': 'TL Chatara',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'PR Stirling'}},
#     {5.6: {'non_striker': 'JA McCollum',
#       'bowler': 'TL Chatara',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'PR Stirling'}},
#     {6.1: {'non_striker': 'PR Stirling',
#       'bowler': 'KM Jarvis',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'JA McCollum'}},
#     {6.2: {'non_striker': 'PR Stirling',
#       'bowler': 'KM Jarvis',
#       'runs': {'extras': 0, 'total': 2, 'batsman': 2},
#       'batsman': 'JA McCollum'}},
#     {6.3: {'non_striker': 'PR Stirling',
#       'bowler': 'KM Jarvis',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'JA McCollum'}},
#     {6.4: {'non_striker': 'PR Stirling',
#       'bowler': 'KM Jarvis',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'JA McCollum'}},
#     {6.5: {'non_striker': 'PR Stirling',
#       'bowler': 'KM Jarvis',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'JA McCollum'}},
#     {6.6: {'non_striker': 'PR Stirling',
#       'bowler': 'KM Jarvis',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'JA McCollum'}},
#     {7.1: {'non_striker': 'PR Stirling',
#       'bowler': 'DT Tiripano',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'JA McCollum'}},
#     {7.2: {'non_striker': 'PR Stirling',
#       'bowler': 'DT Tiripano',
#       'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#       'batsman': 'JA McCollum'}},
#     {7.3: {'non_striker': 'PR Stirling',
#       'bowler': 'DT Tiripano',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'JA McCollum'}},
#     {7.4: {'non_striker': 'PR Stirling',
#       'bowler': 'DT Tiripano',
#       'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#       'batsman': 'JA McCollum'}},
#     {7.5: {'non_striker': 'PR Stirling',
#       'bowler': 'DT Tiripano',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'JA McCollum'}},
#     {7.6: {'non_striker': 'PR Stirling',
#       'bowler': 'DT Tiripano',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'JA McCollum'}},
#     {8.1: {'non_striker': 'JA McCollum',
#       'bowler': 'KM Jarvis',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'PR Stirling'}},
#     {8.2: {'non_striker': 'JA McCollum',
#       'bowler': 'KM Jarvis',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'PR Stirling'}},
#     {8.3: {'non_striker': 'JA McCollum',
#       'bowler': 'KM Jarvis',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'PR Stirling'}},
#     {8.4: {'non_striker': 'PR Stirling',
#       'bowler': 'KM Jarvis',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'JA McCollum'}},
#     {8.5: {'non_striker': 'PR Stirling',
#       'bowler': 'KM Jarvis',
#       'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#       'batsman': 'JA McCollum'}},
#     {8.6: {'non_striker': 'PR Stirling',
#       'bowler': 'KM Jarvis',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'JA McCollum'}},
#     {9.1: {'non_striker': 'JA McCollum',
#       'bowler': 'DT Tiripano',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'PR Stirling'}},
#     {9.2: {'non_striker': 'JA McCollum',
#       'bowler': 'DT Tiripano',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'PR Stirling'}},
#     {9.3: {'non_striker': 'JA McCollum',
#       'bowler': 'DT Tiripano',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'PR Stirling'}},
#     {9.4: {'non_striker': 'PR Stirling',
#       'bowler': 'DT Tiripano',
#       'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#       'batsman': 'JA McCollum'}},
#     {9.5: {'non_striker': 'PR Stirling',
#       'bowler': 'DT Tiripano',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'JA McCollum'}},
#     {9.6: {'non_striker': 'PR Stirling',
#       'bowler': 'DT Tiripano',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'JA McCollum'}},
#     {10.1: {'non_striker': 'JA McCollum',
#       'bowler': 'SC Williams',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'PR Stirling'}},
#     {10.2: {'non_striker': 'PR Stirling',
#       'bowler': 'SC Williams',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'JA McCollum'}},
#     {10.3: {'non_striker': 'JA McCollum',
#       'bowler': 'SC Williams',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'PR Stirling'}},
#     {10.4: {'non_striker': 'PR Stirling',
#       'bowler': 'SC Williams',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'JA McCollum'}},
#     {10.5: {'non_striker': 'PR Stirling',
#       'bowler': 'SC Williams',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'JA McCollum'}},
#     {10.6: {'non_striker': 'PR Stirling',
#       'bowler': 'SC Williams',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'JA McCollum'}},
#     {11.1: {'non_striker': 'JA McCollum',
#       'bowler': 'DT Tiripano',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'PR Stirling'}},
#     {11.2: {'non_striker': 'JA McCollum',
#       'bowler': 'DT Tiripano',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'PR Stirling'}},
#     {11.3: {'non_striker': 'JA McCollum',
#       'bowler': 'DT Tiripano',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'PR Stirling'}},
#     {11.4: {'non_striker': 'JA McCollum',
#       'bowler': 'DT Tiripano',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'PR Stirling'}},
#     {11.5: {'non_striker': 'JA McCollum',
#       'bowler': 'DT Tiripano',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'PR Stirling'}},
#     {11.6: {'non_striker': 'JA McCollum',
#       'bowler': 'DT Tiripano',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'PR Stirling'}},
#     {12.1: {'non_striker': 'PR Stirling',
#       'bowler': 'SC Williams',
#       'runs': {'extras': 1, 'total': 1, 'batsman': 0},
#       'extras': {'wides': 1},
#       'batsman': 'JA McCollum'}},
#     {12.2: {'non_striker': 'PR Stirling',
#       'bowler': 'SC Williams',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'JA McCollum'}},
#     {12.3: {'non_striker': 'PR Stirling',
#       'bowler': 'SC Williams',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'JA McCollum'}},
#     {12.4: {'non_striker': 'PR Stirling',
#       'bowler': 'SC Williams',
#       'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#       'batsman': 'JA McCollum'}},
#     {12.5: {'non_striker': 'PR Stirling',
#       'bowler': 'SC Williams',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'JA McCollum'}},
#     {12.6: {'non_striker': 'JA McCollum',
#       'bowler': 'SC Williams',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'PR Stirling'}},
#     {12.7: {'non_striker': 'JA McCollum',
#       'bowler': 'SC Williams',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'PR Stirling'}},
#     {13.1: {'non_striker': 'JA McCollum',
#       'bowler': 'DT Tiripano',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'PR Stirling'}},
#     {13.2: {'non_striker': 'JA McCollum',
#       'bowler': 'DT Tiripano',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'PR Stirling'}},
#     {13.3: {'non_striker': 'JA McCollum',
#       'bowler': 'DT Tiripano',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'PR Stirling'}},
#     {13.4: {'non_striker': 'PR Stirling',
#       'bowler': 'DT Tiripano',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'JA McCollum'}},
#     {13.5: {'non_striker': 'JA McCollum',
#       'bowler': 'DT Tiripano',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'PR Stirling'}},
#     {13.6: {'non_striker': 'JA McCollum',
#       'bowler': 'DT Tiripano',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'PR Stirling'}},
#     {14.1: {'non_striker': 'JA McCollum',
#       'bowler': 'SC Williams',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'PR Stirling'}},
#     {14.2: {'non_striker': 'PR Stirling',
#       'bowler': 'SC Williams',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'JA McCollum'}},
#     {14.3: {'non_striker': 'PR Stirling',
#       'bowler': 'SC Williams',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'JA McCollum'}},
#     {14.4: {'non_striker': 'PR Stirling',
#       'bowler': 'SC Williams',
#       'runs': {'extras': 0, 'total': 2, 'batsman': 2},
#       'batsman': 'JA McCollum'}},
#     {14.5: {'non_striker': 'PR Stirling',
#       'bowler': 'SC Williams',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'JA McCollum'}},
#     {14.6: {'non_striker': 'PR Stirling',
#       'bowler': 'SC Williams',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'JA McCollum'}},
#     {15.1: {'non_striker': 'JA McCollum',
#       'bowler': 'DT Tiripano',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'PR Stirling'}},
#     {15.2: {'non_striker': 'PR Stirling',
#       'bowler': 'DT Tiripano',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'JA McCollum'}},
#     {15.3: {'non_striker': 'JA McCollum',
#       'bowler': 'DT Tiripano',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'PR Stirling'}},
#     {15.4: {'non_striker': 'JA McCollum',
#       'bowler': 'DT Tiripano',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'PR Stirling'}},
#     {15.5: {'non_striker': 'PR Stirling',
#       'bowler': 'DT Tiripano',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'JA McCollum'}},
#     {15.6: {'non_striker': 'JA McCollum',
#       'bowler': 'DT Tiripano',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'PR Stirling'}},
#     {16.1: {'non_striker': 'JA McCollum',
#       'bowler': 'SC Williams',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'PR Stirling'}},
#     {16.2: {'non_striker': 'JA McCollum',
#       'bowler': 'SC Williams',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'PR Stirling'}},
#     {16.3: {'non_striker': 'PR Stirling',
#       'bowler': 'SC Williams',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'JA McCollum'}},
#     {16.4: {'non_striker': 'JA McCollum',
#       'bowler': 'SC Williams',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'PR Stirling'}},
#     {16.5: {'non_striker': 'PR Stirling',
#       'bowler': 'SC Williams',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'JA McCollum'}},
#     {16.6: {'non_striker': 'PR Stirling',
#       'bowler': 'SC Williams',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'JA McCollum'}},
#     {17.1: {'non_striker': 'JA McCollum',
#       'bowler': 'DT Tiripano',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'PR Stirling'}},
#     {17.2: {'non_striker': 'PR Stirling',
#       'bowler': 'DT Tiripano',
#       'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#       'batsman': 'JA McCollum'}},
#     {17.3: {'non_striker': 'PR Stirling',
#       'bowler': 'DT Tiripano',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'JA McCollum'}},
#     {17.4: {'non_striker': 'PR Stirling',
#       'bowler': 'DT Tiripano',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'JA McCollum'}},
#     {17.5: {'non_striker': 'JA McCollum',
#       'bowler': 'DT Tiripano',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'PR Stirling'}},
#     {17.6: {'non_striker': 'JA McCollum',
#       'bowler': 'DT Tiripano',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'PR Stirling'}},
#     {18.1: {'non_striker': 'JA McCollum',
#       'bowler': 'RP Burl',
#       'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#       'batsman': 'PR Stirling'}},
#     {18.2: {'non_striker': 'JA McCollum',
#       'bowler': 'RP Burl',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'PR Stirling'}},
#     {18.3: {'non_striker': 'PR Stirling',
#       'bowler': 'RP Burl',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'JA McCollum'}},
#     {18.4: {'non_striker': 'PR Stirling',
#       'bowler': 'RP Burl',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'JA McCollum'}},
#     {18.5: {'non_striker': 'JA McCollum',
#       'bowler': 'RP Burl',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'PR Stirling'}},
#     {18.6: {'non_striker': 'JA McCollum',
#       'bowler': 'RP Burl',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'PR Stirling'}},
#     {19.1: {'non_striker': 'JA McCollum',
#       'bowler': 'TL Chatara',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'PR Stirling'}},
#     {19.2: {'non_striker': 'JA McCollum',
#       'bowler': 'TL Chatara',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'PR Stirling'}},
#     {19.3: {'non_striker': 'JA McCollum',
#       'bowler': 'TL Chatara',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'PR Stirling'}},
#     {19.4: {'non_striker': 'JA McCollum',
#       'bowler': 'TL Chatara',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'PR Stirling'}},
#     {19.5: {'non_striker': 'PR Stirling',
#       'bowler': 'TL Chatara',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'JA McCollum'}},
#     {19.6: {'non_striker': 'PR Stirling',
#       'bowler': 'TL Chatara',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'JA McCollum'}},
#     {20.1: {'non_striker': 'JA McCollum',
#       'bowler': 'RP Burl',
#       'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#       'batsman': 'PR Stirling'}},
#     {20.2: {'non_striker': 'JA McCollum',
#       'bowler': 'RP Burl',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'PR Stirling'}},
#     {20.3: {'non_striker': 'PR Stirling',
#       'bowler': 'RP Burl',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'JA McCollum'}},
#     {20.4: {'non_striker': 'PR Stirling',
#       'bowler': 'RP Burl',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'JA McCollum'}},
#     {20.5: {'non_striker': 'PR Stirling',
#       'bowler': 'RP Burl',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'JA McCollum'}},
#     {20.6: {'non_striker': 'JA McCollum',
#       'bowler': 'RP Burl',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'PR Stirling'}},
#     {21.1: {'non_striker': 'JA McCollum',
#       'bowler': 'TL Chatara',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'PR Stirling'}},
#     {21.2: {'non_striker': 'JA McCollum',
#       'bowler': 'TL Chatara',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'PR Stirling'}},
#     {21.3: {'non_striker': 'JA McCollum',
#       'bowler': 'TL Chatara',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'PR Stirling'}},
#     {21.4: {'non_striker': 'PR Stirling',
#       'bowler': 'TL Chatara',
#       'runs': {'extras': 1, 'total': 1, 'batsman': 0},
#       'extras': {'byes': 1},
#       'batsman': 'JA McCollum'}},
#     {21.5: {'non_striker': 'JA McCollum',
#       'bowler': 'TL Chatara',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'PR Stirling'}},
#     {21.6: {'non_striker': 'JA McCollum',
#       'bowler': 'TL Chatara',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'PR Stirling'}},
#     {22.1: {'non_striker': 'PR Stirling',
#       'bowler': 'RP Burl',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'JA McCollum'}},
#     {22.2: {'non_striker': 'PR Stirling',
#       'bowler': 'RP Burl',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'JA McCollum'}},
#     {22.3: {'non_striker': 'PR Stirling',
#       'bowler': 'RP Burl',
#       'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#       'batsman': 'JA McCollum'}},
#     {22.4: {'non_striker': 'PR Stirling',
#       'bowler': 'RP Burl',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'JA McCollum'}},
#     {22.5: {'non_striker': 'JA McCollum',
#       'bowler': 'RP Burl',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'PR Stirling'}},
#     {22.6: {'non_striker': 'PR Stirling',
#       'bowler': 'RP Burl',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'JA McCollum'}},
#     {23.1: {'non_striker': 'JA McCollum',
#       'bowler': 'SF Mire',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'PR Stirling'}},
#     {23.2: {'non_striker': 'PR Stirling',
#       'bowler': 'SF Mire',
#       'runs': {'extras': 3, 'total': 3, 'batsman': 0},
#       'extras': {'wides': 3},
#       'batsman': 'JA McCollum'}},
#     {23.3: {'non_striker': 'PR Stirling',
#       'bowler': 'SF Mire',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'JA McCollum'}},
#     {23.4: {'non_striker': 'JA McCollum',
#       'bowler': 'SF Mire',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'PR Stirling'}},
#     {23.5: {'non_striker': 'JA McCollum',
#       'bowler': 'SF Mire',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'PR Stirling'}},
#     {23.6: {'non_striker': 'PR Stirling',
#       'bowler': 'SF Mire',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'JA McCollum'}},
#     {23.7: {'non_striker': 'JA McCollum',
#       'bowler': 'SF Mire',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'PR Stirling',
#       'wicket': {'player_out': 'PR Stirling',
#        'fielders': ['SC Williams'],
#        'kind': 'caught'}}},
#     {24.1: {'non_striker': 'A Balbirnie',
#       'bowler': 'RP Burl',
#       'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#       'batsman': 'JA McCollum'}},
#     {24.2: {'non_striker': 'A Balbirnie',
#       'bowler': 'RP Burl',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'JA McCollum'}},
#     {24.3: {'non_striker': 'JA McCollum',
#       'bowler': 'RP Burl',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'A Balbirnie'}},
#     {24.4: {'non_striker': 'JA McCollum',
#       'bowler': 'RP Burl',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'A Balbirnie'}},
#     {24.5: {'non_striker': 'A Balbirnie',
#       'bowler': 'RP Burl',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'JA McCollum'}},
#     {24.6: {'non_striker': 'A Balbirnie',
#       'bowler': 'RP Burl',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'JA McCollum'}},
#     {25.1: {'non_striker': 'A Balbirnie',
#       'bowler': 'SF Mire',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'JA McCollum'}},
#     {25.2: {'non_striker': 'A Balbirnie',
#       'bowler': 'SF Mire',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'JA McCollum'}},
#     {25.3: {'non_striker': 'JA McCollum',
#       'bowler': 'SF Mire',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'A Balbirnie'}},
#     {25.4: {'non_striker': 'JA McCollum',
#       'bowler': 'SF Mire',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'A Balbirnie'}},
#     {25.5: {'non_striker': 'A Balbirnie',
#       'bowler': 'SF Mire',
#       'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#       'batsman': 'JA McCollum'}},
#     {25.6: {'non_striker': 'A Balbirnie',
#       'bowler': 'SF Mire',
#       'runs': {'extras': 1, 'total': 1, 'batsman': 0},
#       'extras': {'legbyes': 1},
#       'batsman': 'JA McCollum'}},
#     {26.1: {'non_striker': 'A Balbirnie',
#       'bowler': 'KM Jarvis',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'JA McCollum'}},
#     {26.2: {'non_striker': 'JA McCollum',
#       'bowler': 'KM Jarvis',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'A Balbirnie'}},
#     {26.3: {'non_striker': 'JA McCollum',
#       'bowler': 'KM Jarvis',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'A Balbirnie'}},
#     {26.4: {'non_striker': 'JA McCollum',
#       'bowler': 'KM Jarvis',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'A Balbirnie'}},
#     {26.5: {'non_striker': 'JA McCollum',
#       'bowler': 'KM Jarvis',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'A Balbirnie'}},
#     {26.6: {'non_striker': 'A Balbirnie',
#       'bowler': 'KM Jarvis',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'JA McCollum'}},
#     {27.1: {'non_striker': 'JA McCollum',
#       'bowler': 'SF Mire',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'A Balbirnie'}},
#     {27.2: {'non_striker': 'JA McCollum',
#       'bowler': 'SF Mire',
#       'runs': {'extras': 0, 'total': 2, 'batsman': 2},
#       'batsman': 'A Balbirnie'}},
#     {27.3: {'non_striker': 'JA McCollum',
#       'bowler': 'SF Mire',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'A Balbirnie'}},
#     {27.4: {'non_striker': 'JA McCollum',
#       'bowler': 'SF Mire',
#       'runs': {'extras': 1, 'total': 1, 'batsman': 0},
#       'extras': {'wides': 1},
#       'batsman': 'A Balbirnie'}},
#     {27.5: {'non_striker': 'JA McCollum',
#       'bowler': 'SF Mire',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'A Balbirnie'}},
#     {27.6: {'non_striker': 'A Balbirnie',
#       'bowler': 'SF Mire',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'JA McCollum'}},
#     {27.7: {'non_striker': 'JA McCollum',
#       'bowler': 'SF Mire',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'A Balbirnie'}},
#     {28.1: {'non_striker': 'A Balbirnie',
#       'bowler': 'KM Jarvis',
#       'runs': {'extras': 0, 'total': 2, 'batsman': 2},
#       'batsman': 'JA McCollum'}},
#     {28.2: {'non_striker': 'A Balbirnie',
#       'bowler': 'KM Jarvis',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'JA McCollum'}},
#     {28.3: {'non_striker': 'A Balbirnie',
#       'bowler': 'KM Jarvis',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'JA McCollum'}},
#     {28.4: {'non_striker': 'A Balbirnie',
#       'bowler': 'KM Jarvis',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'JA McCollum'}},
#     {28.5: {'non_striker': 'A Balbirnie',
#       'bowler': 'KM Jarvis',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'JA McCollum'}},
#     {28.6: {'non_striker': 'A Balbirnie',
#       'bowler': 'KM Jarvis',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'JA McCollum'}},
#     {29.1: {'non_striker': 'A Balbirnie',
#       'bowler': 'SF Mire',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'JA McCollum'}},
#     {29.2: {'non_striker': 'JA McCollum',
#       'bowler': 'SF Mire',
#       'runs': {'extras': 0, 'total': 2, 'batsman': 2},
#       'batsman': 'A Balbirnie'}},
#     {29.3: {'non_striker': 'JA McCollum',
#       'bowler': 'SF Mire',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'A Balbirnie'}},
#     {29.4: {'non_striker': 'A Balbirnie',
#       'bowler': 'SF Mire',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'JA McCollum'}},
#     {29.5: {'non_striker': 'JA McCollum',
#       'bowler': 'SF Mire',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'A Balbirnie'}},
#     {29.6: {'non_striker': 'JA McCollum',
#       'bowler': 'SF Mire',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'A Balbirnie',
#       'wicket': {'player_out': 'A Balbirnie',
#        'fielders': ['BRM Taylor'],
#        'kind': 'caught'}}},
#     {30.1: {'non_striker': 'WTS Porterfield',
#       'bowler': 'TL Chatara',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'JA McCollum'}},
#     {30.2: {'non_striker': 'JA McCollum',
#       'bowler': 'TL Chatara',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'WTS Porterfield'}},
#     {30.3: {'non_striker': 'JA McCollum',
#       'bowler': 'TL Chatara',
#       'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#       'batsman': 'WTS Porterfield'}},
#     {30.4: {'non_striker': 'JA McCollum',
#       'bowler': 'TL Chatara',
#       'runs': {'extras': 0, 'total': 2, 'batsman': 2},
#       'batsman': 'WTS Porterfield'}},
#     {30.5: {'non_striker': 'JA McCollum',
#       'bowler': 'TL Chatara',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'WTS Porterfield'}},
#     {30.6: {'non_striker': 'JA McCollum',
#       'bowler': 'TL Chatara',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'WTS Porterfield'}},
#     {31.1: {'non_striker': 'WTS Porterfield',
#       'bowler': 'SF Mire',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'JA McCollum',
#       'wicket': {'player_out': 'JA McCollum',
#        'fielders': ['Sikandar Raza'],
#        'kind': 'caught'}}},
#     {31.2: {'non_striker': "KJ O'Brien",
#       'bowler': 'SF Mire',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'WTS Porterfield'}},
#     {31.3: {'non_striker': "KJ O'Brien",
#       'bowler': 'SF Mire',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'WTS Porterfield'}},
#     {31.4: {'non_striker': "KJ O'Brien",
#       'bowler': 'SF Mire',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'WTS Porterfield'}},
#     {31.5: {'non_striker': "KJ O'Brien",
#       'bowler': 'SF Mire',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'WTS Porterfield'}},
#     {31.6: {'non_striker': "KJ O'Brien",
#       'bowler': 'SF Mire',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'WTS Porterfield'}},
#     {32.1: {'non_striker': 'WTS Porterfield',
#       'bowler': 'TL Chatara',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': "KJ O'Brien"}},
#     {32.2: {'non_striker': "KJ O'Brien",
#       'bowler': 'TL Chatara',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'WTS Porterfield'}},
#     {32.3: {'non_striker': "KJ O'Brien",
#       'bowler': 'TL Chatara',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'WTS Porterfield'}},
#     {32.4: {'non_striker': 'WTS Porterfield',
#       'bowler': 'TL Chatara',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': "KJ O'Brien"}},
#     {32.5: {'non_striker': "KJ O'Brien",
#       'bowler': 'TL Chatara',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'WTS Porterfield'}},
#     {32.6: {'non_striker': "KJ O'Brien",
#       'bowler': 'TL Chatara',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'WTS Porterfield'}},
#     {33.1: {'non_striker': 'WTS Porterfield',
#       'bowler': 'SF Mire',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': "KJ O'Brien"}},
#     {33.2: {'non_striker': 'WTS Porterfield',
#       'bowler': 'SF Mire',
#       'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#       'batsman': "KJ O'Brien"}},
#     {33.3: {'non_striker': 'WTS Porterfield',
#       'bowler': 'SF Mire',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': "KJ O'Brien"}},
#     {33.4: {'non_striker': 'WTS Porterfield',
#       'bowler': 'SF Mire',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': "KJ O'Brien",
#       'wicket': {'player_out': "KJ O'Brien",
#        'fielders': ['CR Ervine'],
#        'kind': 'caught'}}},
#     {33.5: {'non_striker': 'WTS Porterfield',
#       'bowler': 'SF Mire',
#       'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#       'batsman': 'L Tucker'}},
#     {33.6: {'non_striker': 'WTS Porterfield',
#       'bowler': 'SF Mire',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'L Tucker'}},
#     {34.1: {'non_striker': 'L Tucker',
#       'bowler': 'Sikandar Raza',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'WTS Porterfield'}},
#     {34.2: {'non_striker': 'L Tucker',
#       'bowler': 'Sikandar Raza',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'WTS Porterfield'}},
#     {34.3: {'non_striker': 'L Tucker',
#       'bowler': 'Sikandar Raza',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'WTS Porterfield'}},
#     {34.4: {'non_striker': 'L Tucker',
#       'bowler': 'Sikandar Raza',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'WTS Porterfield'}},
#     {34.5: {'non_striker': 'L Tucker',
#       'bowler': 'Sikandar Raza',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'WTS Porterfield'}},
#     {34.6: {'non_striker': 'WTS Porterfield',
#       'bowler': 'Sikandar Raza',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'L Tucker'}},
#     {35.1: {'non_striker': 'WTS Porterfield',
#       'bowler': 'SF Mire',
#       'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#       'batsman': 'L Tucker'}},
#     {35.2: {'non_striker': 'WTS Porterfield',
#       'bowler': 'SF Mire',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'L Tucker'}},
#     {35.3: {'non_striker': 'WTS Porterfield',
#       'bowler': 'SF Mire',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'L Tucker'}},
#     {35.4: {'non_striker': 'WTS Porterfield',
#       'bowler': 'SF Mire',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'L Tucker'}},
#     {35.5: {'non_striker': 'L Tucker',
#       'bowler': 'SF Mire',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'WTS Porterfield'}},
#     {35.6: {'non_striker': 'L Tucker',
#       'bowler': 'SF Mire',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'WTS Porterfield'}},
#     {36.1: {'non_striker': 'L Tucker',
#       'bowler': 'Sikandar Raza',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'WTS Porterfield'}},
#     {36.2: {'non_striker': 'WTS Porterfield',
#       'bowler': 'Sikandar Raza',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'L Tucker'}},
#     {36.3: {'non_striker': 'L Tucker',
#       'bowler': 'Sikandar Raza',
#       'runs': {'extras': 0, 'total': 2, 'batsman': 2},
#       'batsman': 'WTS Porterfield'}},
#     {36.4: {'non_striker': 'L Tucker',
#       'bowler': 'Sikandar Raza',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'WTS Porterfield'}},
#     {36.5: {'non_striker': 'L Tucker',
#       'bowler': 'Sikandar Raza',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'WTS Porterfield'}},
#     {36.6: {'non_striker': 'L Tucker',
#       'bowler': 'Sikandar Raza',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'WTS Porterfield'}},
#     {37.1: {'non_striker': 'L Tucker',
#       'bowler': 'SF Mire',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'WTS Porterfield'}},
#     {37.2: {'non_striker': 'L Tucker',
#       'bowler': 'SF Mire',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'WTS Porterfield'}},
#     {37.3: {'non_striker': 'L Tucker',
#       'bowler': 'SF Mire',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'WTS Porterfield'}},
#     {37.4: {'non_striker': 'L Tucker',
#       'bowler': 'SF Mire',
#       'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#       'batsman': 'WTS Porterfield'}},
#     {37.5: {'non_striker': 'L Tucker',
#       'bowler': 'SF Mire',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'WTS Porterfield'}},
#     {37.6: {'non_striker': 'WTS Porterfield',
#       'bowler': 'SF Mire',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'L Tucker'}},
#     {38.1: {'non_striker': 'WTS Porterfield',
#       'bowler': 'Sikandar Raza',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'L Tucker'}},
#     {38.2: {'non_striker': 'WTS Porterfield',
#       'bowler': 'Sikandar Raza',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'L Tucker'}},
#     {38.3: {'non_striker': 'WTS Porterfield',
#       'bowler': 'Sikandar Raza',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'L Tucker'}},
#     {38.4: {'non_striker': 'L Tucker',
#       'bowler': 'Sikandar Raza',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'WTS Porterfield'}},
#     {38.5: {'non_striker': 'L Tucker',
#       'bowler': 'Sikandar Raza',
#       'runs': {'extras': 0, 'total': 2, 'batsman': 2},
#       'batsman': 'WTS Porterfield'}},
#     {38.6: {'non_striker': 'L Tucker',
#       'bowler': 'Sikandar Raza',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'WTS Porterfield'}},
#     {39.1: {'non_striker': 'WTS Porterfield',
#       'bowler': 'DT Tiripano',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'L Tucker'}},
#     {39.2: {'non_striker': 'WTS Porterfield',
#       'bowler': 'DT Tiripano',
#       'runs': {'extras': 0, 'total': 2, 'batsman': 2},
#       'batsman': 'L Tucker'}},
#     {39.3: {'non_striker': 'WTS Porterfield',
#       'bowler': 'DT Tiripano',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'L Tucker'}},
#     {39.4: {'non_striker': 'WTS Porterfield',
#       'bowler': 'DT Tiripano',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'L Tucker'}},
#     {39.5: {'non_striker': 'WTS Porterfield',
#       'bowler': 'DT Tiripano',
#       'runs': {'extras': 0, 'total': 2, 'batsman': 2},
#       'batsman': 'L Tucker'}},
#     {39.6: {'non_striker': 'WTS Porterfield',
#       'bowler': 'DT Tiripano',
#       'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#       'batsman': 'L Tucker'}},
#     {40.1: {'non_striker': 'L Tucker',
#       'bowler': 'Sikandar Raza',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'WTS Porterfield'}},
#     {40.2: {'non_striker': 'L Tucker',
#       'bowler': 'Sikandar Raza',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'WTS Porterfield',
#       'wicket': {'player_out': 'WTS Porterfield',
#        'fielders': ['SC Williams'],
#        'kind': 'caught'}}},
#     {40.3: {'non_striker': 'L Tucker',
#       'bowler': 'Sikandar Raza',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'SC Getkate'}},
#     {40.4: {'non_striker': 'L Tucker',
#       'bowler': 'Sikandar Raza',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'SC Getkate'}},
#     {40.5: {'non_striker': 'L Tucker',
#       'bowler': 'Sikandar Raza',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'SC Getkate'}},
#     {40.6: {'non_striker': 'L Tucker',
#       'bowler': 'Sikandar Raza',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'SC Getkate'}},
#     {41.1: {'non_striker': 'SC Getkate',
#       'bowler': 'SC Williams',
#       'runs': {'extras': 0, 'total': 2, 'batsman': 2},
#       'batsman': 'L Tucker'}},
#     {41.2: {'non_striker': 'SC Getkate',
#       'bowler': 'SC Williams',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'L Tucker'}},
#     {41.3: {'non_striker': 'SC Getkate',
#       'bowler': 'SC Williams',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'L Tucker'}},
#     {41.4: {'non_striker': 'SC Getkate',
#       'bowler': 'SC Williams',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'L Tucker'}},
#     {41.5: {'non_striker': 'SC Getkate',
#       'bowler': 'SC Williams',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'L Tucker'}},
#     {41.6: {'non_striker': 'L Tucker',
#       'bowler': 'SC Williams',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'SC Getkate'}},
#     {42.1: {'non_striker': 'SC Getkate',
#       'bowler': 'Sikandar Raza',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'L Tucker'}},
#     {42.2: {'non_striker': 'L Tucker',
#       'bowler': 'Sikandar Raza',
#       'runs': {'extras': 0, 'total': 2, 'batsman': 2},
#       'batsman': 'SC Getkate'}},
#     {42.3: {'non_striker': 'L Tucker',
#       'bowler': 'Sikandar Raza',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'SC Getkate'}},
#     {42.4: {'non_striker': 'SC Getkate',
#       'bowler': 'Sikandar Raza',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'L Tucker'}},
#     {42.5: {'non_striker': 'SC Getkate',
#       'bowler': 'Sikandar Raza',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'L Tucker'}},
#     {42.6: {'non_striker': 'L Tucker',
#       'bowler': 'Sikandar Raza',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'SC Getkate'}},
#     {43.1: {'non_striker': 'SC Getkate',
#       'bowler': 'SC Williams',
#       'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#       'batsman': 'L Tucker'}},
#     {43.2: {'non_striker': 'SC Getkate',
#       'bowler': 'SC Williams',
#       'runs': {'extras': 1, 'total': 1, 'batsman': 0},
#       'extras': {'wides': 1},
#       'batsman': 'L Tucker'}},
#     {43.3: {'non_striker': 'SC Getkate',
#       'bowler': 'SC Williams',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'L Tucker'}},
#     {43.4: {'non_striker': 'SC Getkate',
#       'bowler': 'SC Williams',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'L Tucker'}},
#     {43.5: {'non_striker': 'L Tucker',
#       'bowler': 'SC Williams',
#       'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#       'batsman': 'SC Getkate'}},
#     {43.6: {'non_striker': 'L Tucker',
#       'bowler': 'SC Williams',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'SC Getkate',
#       'wicket': {'player_out': 'SC Getkate', 'kind': 'bowled'}}},
#     {43.7: {'non_striker': 'L Tucker',
#       'bowler': 'SC Williams',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'MR Adair'}},
#     {44.1: {'non_striker': 'L Tucker',
#       'bowler': 'Sikandar Raza',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'MR Adair'}},
#     {44.2: {'non_striker': 'L Tucker',
#       'bowler': 'Sikandar Raza',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'MR Adair'}},
#     {44.3: {'non_striker': 'MR Adair',
#       'bowler': 'Sikandar Raza',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'L Tucker'}},
#     {44.4: {'non_striker': 'MR Adair',
#       'bowler': 'Sikandar Raza',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'L Tucker'}},
#     {44.5: {'non_striker': 'L Tucker',
#       'bowler': 'Sikandar Raza',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'MR Adair'}},
#     {44.6: {'non_striker': 'MR Adair',
#       'bowler': 'Sikandar Raza',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'L Tucker'}},
#     {45.1: {'non_striker': 'MR Adair',
#       'bowler': 'SC Williams',
#       'runs': {'extras': 1, 'total': 1, 'batsman': 0},
#       'extras': {'legbyes': 1},
#       'batsman': 'L Tucker'}},
#     {45.2: {'non_striker': 'L Tucker',
#       'bowler': 'SC Williams',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'MR Adair',
#       'wicket': {'player_out': 'MR Adair',
#        'fielders': ['R Mutumbami'],
#        'kind': 'caught'}}},
#     {45.3: {'non_striker': 'L Tucker',
#       'bowler': 'SC Williams',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'AR McBrine'}},
#     {45.4: {'non_striker': 'AR McBrine',
#       'bowler': 'SC Williams',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'L Tucker'}},
#     {45.5: {'non_striker': 'AR McBrine',
#       'bowler': 'SC Williams',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'L Tucker'}},
#     {45.6: {'non_striker': 'L Tucker',
#       'bowler': 'SC Williams',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'AR McBrine'}},
#     {46.1: {'non_striker': 'AR McBrine',
#       'bowler': 'Sikandar Raza',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'L Tucker'}},
#     {46.2: {'non_striker': 'L Tucker',
#       'bowler': 'Sikandar Raza',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'AR McBrine'}},
#     {46.3: {'non_striker': 'AR McBrine',
#       'bowler': 'Sikandar Raza',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'L Tucker'}},
#     {46.4: {'non_striker': 'AR McBrine',
#       'bowler': 'Sikandar Raza',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'L Tucker'}},
#     {46.5: {'non_striker': 'L Tucker',
#       'bowler': 'Sikandar Raza',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'AR McBrine'}},
#     {46.6: {'non_striker': 'AR McBrine',
#       'bowler': 'Sikandar Raza',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'L Tucker'}},
#     {47.1: {'non_striker': 'AR McBrine',
#       'bowler': 'SC Williams',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'L Tucker'}},
#     {47.2: {'non_striker': 'L Tucker',
#       'bowler': 'SC Williams',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'AR McBrine'}},
#     {47.3: {'non_striker': 'AR McBrine',
#       'bowler': 'SC Williams',
#       'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#       'batsman': 'L Tucker'}},
#     {47.4: {'non_striker': 'AR McBrine',
#       'bowler': 'SC Williams',
#       'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#       'batsman': 'L Tucker'}},
#     {47.5: {'non_striker': 'AR McBrine',
#       'bowler': 'SC Williams',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'L Tucker'}},
#     {47.6: {'non_striker': 'AR McBrine',
#       'bowler': 'SC Williams',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'L Tucker'}},
#     {48.1: {'non_striker': 'AR McBrine',
#       'bowler': 'Sikandar Raza',
#       'runs': {'extras': 0, 'total': 2, 'batsman': 2},
#       'batsman': 'L Tucker'}},
#     {48.2: {'non_striker': 'AR McBrine',
# ...
#       'batsman': 'R Mutumbami',
#       'wicket': {'player_out': 'R Mutumbami',
#        'fielders': ['L Tucker'],
#        'kind': 'caught'}}},
#     {33.3: {'non_striker': 'RP Burl',
#       'bowler': 'SC Getkate',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'DT Tiripano'}},
#     {33.4: {'non_striker': 'RP Burl',
#       'bowler': 'SC Getkate',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'DT Tiripano'}},
#     {33.5: {'non_striker': 'RP Burl',
#       'bowler': 'SC Getkate',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'DT Tiripano'}},
#     {33.6: {'non_striker': 'RP Burl',
#       'bowler': 'SC Getkate',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'DT Tiripano'}},
#     {34.1: {'non_striker': 'DT Tiripano',
#       'bowler': 'WB Rankin',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'RP Burl'}},
#     {34.2: {'non_striker': 'RP Burl',
#       'bowler': 'WB Rankin',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'DT Tiripano'}},
#     {34.3: {'non_striker': 'RP Burl',
#       'bowler': 'WB Rankin',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'DT Tiripano'}},
#     {34.4: {'non_striker': 'RP Burl',
#       'bowler': 'WB Rankin',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'DT Tiripano'}},
#     {34.5: {'non_striker': 'DT Tiripano',
#       'bowler': 'WB Rankin',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'RP Burl'}},
#     {34.6: {'non_striker': 'DT Tiripano',
#       'bowler': 'WB Rankin',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'RP Burl'}},
#     {35.1: {'non_striker': 'RP Burl',
#       'bowler': 'MR Adair',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'DT Tiripano'}},
#     {35.2: {'non_striker': 'RP Burl',
#       'bowler': 'MR Adair',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'DT Tiripano'}},
#     {35.3: {'non_striker': 'RP Burl',
#       'bowler': 'MR Adair',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'DT Tiripano'}},
#     {35.4: {'non_striker': 'DT Tiripano',
#       'bowler': 'MR Adair',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'RP Burl'}},
#     {35.5: {'non_striker': 'DT Tiripano',
#       'bowler': 'MR Adair',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'RP Burl'}},
#     {35.6: {'non_striker': 'DT Tiripano',
#       'bowler': 'MR Adair',
#       'runs': {'extras': 1, 'total': 1, 'batsman': 0},
#       'extras': {'legbyes': 1},
#       'batsman': 'RP Burl'}},
#     {36.1: {'non_striker': 'DT Tiripano',
#       'bowler': "KJ O'Brien",
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'RP Burl'}},
#     {36.2: {'non_striker': 'DT Tiripano',
#       'bowler': "KJ O'Brien",
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'RP Burl'}},
#     {36.3: {'non_striker': 'DT Tiripano',
#       'bowler': "KJ O'Brien",
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'RP Burl'}},
#     {36.4: {'non_striker': 'RP Burl',
#       'bowler': "KJ O'Brien",
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'DT Tiripano'}},
#     {36.5: {'non_striker': 'DT Tiripano',
#       'bowler': "KJ O'Brien",
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'RP Burl'}},
#     {36.6: {'non_striker': 'RP Burl',
#       'bowler': "KJ O'Brien",
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'DT Tiripano'}},
#     {37.1: {'non_striker': 'DT Tiripano',
#       'bowler': 'MR Adair',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'RP Burl'}},
#     {37.2: {'non_striker': 'RP Burl',
#       'bowler': 'MR Adair',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'DT Tiripano'}},
#     {37.3: {'non_striker': 'DT Tiripano',
#       'bowler': 'MR Adair',
#       'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#       'batsman': 'RP Burl'}},
#     {37.4: {'non_striker': 'DT Tiripano',
#       'bowler': 'MR Adair',
#       'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#       'batsman': 'RP Burl'}},
#     {37.5: {'non_striker': 'DT Tiripano',
#       'bowler': 'MR Adair',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'RP Burl'}},
#     {37.6: {'non_striker': 'DT Tiripano',
#       'bowler': 'MR Adair',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'RP Burl'}},
#     {38.1: {'non_striker': 'RP Burl',
#       'bowler': "KJ O'Brien",
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'DT Tiripano'}},
#     {38.2: {'non_striker': 'DT Tiripano',
#       'bowler': "KJ O'Brien",
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'RP Burl'}},
#     {38.3: {'non_striker': 'DT Tiripano',
#       'bowler': "KJ O'Brien",
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'RP Burl'}},
#     {38.4: {'non_striker': 'DT Tiripano',
#       'bowler': "KJ O'Brien",
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'RP Burl'}},
#     {38.5: {'non_striker': 'DT Tiripano',
#       'bowler': "KJ O'Brien",
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'RP Burl'}},
#     {38.6: {'non_striker': 'DT Tiripano',
#       'bowler': "KJ O'Brien",
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'RP Burl'}},
#     {39.1: {'non_striker': 'DT Tiripano',
#       'bowler': 'SC Getkate',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'RP Burl'}},
#     {39.2: {'non_striker': 'DT Tiripano',
#       'bowler': 'SC Getkate',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'RP Burl'}},
#     {39.3: {'non_striker': 'RP Burl',
#       'bowler': 'SC Getkate',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'DT Tiripano'}},
#     {39.4: {'non_striker': 'RP Burl',
#       'bowler': 'SC Getkate',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'DT Tiripano'}},
#     {39.5: {'non_striker': 'DT Tiripano',
#       'bowler': 'SC Getkate',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'RP Burl'}},
#     {39.6: {'non_striker': 'DT Tiripano',
#       'bowler': 'SC Getkate',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'RP Burl'}},
#     {40.1: {'non_striker': 'DT Tiripano',
#       'bowler': "KJ O'Brien",
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'RP Burl'}},
#     {40.2: {'non_striker': 'RP Burl',
#       'bowler': "KJ O'Brien",
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'DT Tiripano'}},
#     {40.3: {'non_striker': 'RP Burl',
#       'bowler': "KJ O'Brien",
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'DT Tiripano'}},
#     {40.4: {'non_striker': 'RP Burl',
#       'bowler': "KJ O'Brien",
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'DT Tiripano'}},
#     {40.5: {'non_striker': 'DT Tiripano',
#       'bowler': "KJ O'Brien",
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'RP Burl'}},
#     {40.6: {'non_striker': 'RP Burl',
#       'bowler': "KJ O'Brien",
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'DT Tiripano'}},
#     {41.1: {'non_striker': 'RP Burl',
#       'bowler': 'SC Getkate',
#       'runs': {'extras': 0, 'total': 2, 'batsman': 2},
#       'batsman': 'DT Tiripano'}},
#     {41.2: {'non_striker': 'RP Burl',
#       'bowler': 'SC Getkate',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'DT Tiripano'}},
#     {41.3: {'non_striker': 'DT Tiripano',
#       'bowler': 'SC Getkate',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'RP Burl'}},
#     {41.4: {'non_striker': 'RP Burl',
#       'bowler': 'SC Getkate',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'DT Tiripano'}},
#     {41.5: {'non_striker': 'DT Tiripano',
#       'bowler': 'SC Getkate',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'RP Burl'}},
#     {41.6: {'non_striker': 'RP Burl',
#       'bowler': 'SC Getkate',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'DT Tiripano'}},
#     {42.1: {'non_striker': 'DT Tiripano',
#       'bowler': 'WB Rankin',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'RP Burl'}},
#     {42.2: {'non_striker': 'DT Tiripano',
#       'bowler': 'WB Rankin',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'RP Burl'}},
#     {42.3: {'non_striker': 'DT Tiripano',
#       'bowler': 'WB Rankin',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'RP Burl'}},
#     {42.4: {'non_striker': 'RP Burl',
#       'bowler': 'WB Rankin',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'DT Tiripano'}},
#     {42.5: {'non_striker': 'RP Burl',
#       'bowler': 'WB Rankin',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'DT Tiripano'}},
#     {42.6: {'non_striker': 'DT Tiripano',
#       'bowler': 'WB Rankin',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'RP Burl'}},
#     {43.1: {'non_striker': 'DT Tiripano',
#       'bowler': 'MR Adair',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'RP Burl'}},
#     {43.2: {'non_striker': 'DT Tiripano',
#       'bowler': 'MR Adair',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'RP Burl'}},
#     {43.3: {'non_striker': 'RP Burl',
#       'bowler': 'MR Adair',
#       'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#       'batsman': 'DT Tiripano'}},
#     {43.4: {'non_striker': 'RP Burl',
#       'bowler': 'MR Adair',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'DT Tiripano'}},
#     {43.5: {'non_striker': 'DT Tiripano',
#       'bowler': 'MR Adair',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'RP Burl'}},
#     {43.6: {'non_striker': 'DT Tiripano',
#       'bowler': 'MR Adair',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'RP Burl'}},
#     {44.1: {'non_striker': 'DT Tiripano',
#       'bowler': 'TJ Murtagh',
#       'runs': {'extras': 0, 'total': 2, 'batsman': 2},
#       'batsman': 'RP Burl'}},
#     {44.2: {'non_striker': 'DT Tiripano',
#       'bowler': 'TJ Murtagh',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'RP Burl'}},
#     {44.3: {'non_striker': 'DT Tiripano',
#       'bowler': 'TJ Murtagh',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'RP Burl'}},
#     {44.4: {'non_striker': 'RP Burl',
#       'bowler': 'TJ Murtagh',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'DT Tiripano'}},
#     {44.5: {'non_striker': 'RP Burl',
#       'bowler': 'TJ Murtagh',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'DT Tiripano'}},
#     {44.6: {'non_striker': 'RP Burl',
#       'bowler': 'TJ Murtagh',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'DT Tiripano'}},
#     {45.1: {'non_striker': 'DT Tiripano',
#       'bowler': 'WB Rankin',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'RP Burl'}},
#     {45.2: {'non_striker': 'RP Burl',
#       'bowler': 'WB Rankin',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'DT Tiripano'}},
#     {45.3: {'non_striker': 'RP Burl',
#       'bowler': 'WB Rankin',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'DT Tiripano'}},
#     {45.4: {'non_striker': 'RP Burl',
#       'bowler': 'WB Rankin',
#       'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#       'batsman': 'DT Tiripano'}},
#     {45.5: {'non_striker': 'RP Burl',
#       'bowler': 'WB Rankin',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'DT Tiripano'}},
#     {45.6: {'non_striker': 'DT Tiripano',
#       'bowler': 'WB Rankin',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'RP Burl'}},
#     {46.1: {'non_striker': 'RP Burl',
#       'bowler': "KJ O'Brien",
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'DT Tiripano'}},
#     {46.2: {'non_striker': 'DT Tiripano',
#       'bowler': "KJ O'Brien",
#       'runs': {'extras': 0, 'total': 2, 'batsman': 2},
#       'batsman': 'RP Burl'}},
#     {46.3: {'non_striker': 'DT Tiripano',
#       'bowler': "KJ O'Brien",
#       'runs': {'extras': 0, 'total': 2, 'batsman': 2},
#       'batsman': 'RP Burl'}},
#     {46.4: {'non_striker': 'DT Tiripano',
#       'bowler': "KJ O'Brien",
#       'runs': {'extras': 1, 'total': 1, 'batsman': 0},
#       'extras': {'legbyes': 1},
#       'batsman': 'RP Burl'}},
#     {46.5: {'non_striker': 'RP Burl',
#       'bowler': "KJ O'Brien",
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'DT Tiripano'}},
#     {46.6: {'non_striker': 'RP Burl',
#       'bowler': "KJ O'Brien",
#       'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#       'batsman': 'DT Tiripano'}},
#     {47.1: {'non_striker': 'DT Tiripano',
#       'bowler': 'SC Getkate',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'RP Burl'}},
#     {47.2: {'non_striker': 'RP Burl',
#       'bowler': 'SC Getkate',
#       'runs': {'extras': 0, 'total': 2, 'batsman': 2},
#       'batsman': 'DT Tiripano'}},
#     {47.3: {'non_striker': 'RP Burl',
#       'bowler': 'SC Getkate',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'DT Tiripano'}},
#     {47.4: {'non_striker': 'RP Burl',
#       'bowler': 'SC Getkate',
#       'runs': {'extras': 0, 'total': 2, 'batsman': 2},
#       'batsman': 'DT Tiripano'}},
#     {47.5: {'non_striker': 'RP Burl',
#       'bowler': 'SC Getkate',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'DT Tiripano'}},
#     {47.6: {'non_striker': 'DT Tiripano',
#       'bowler': 'SC Getkate',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'RP Burl'}},
#     {48.1: {'non_striker': 'DT Tiripano',
#       'bowler': 'TJ Murtagh',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'RP Burl'}},
#     {48.2: {'non_striker': 'DT Tiripano',
#       'bowler': 'TJ Murtagh',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'RP Burl'}},
#     {48.3: {'non_striker': 'DT Tiripano',
#       'bowler': 'TJ Murtagh',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'RP Burl'}},
#     {48.4: {'non_striker': 'RP Burl',
#       'bowler': 'TJ Murtagh',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'DT Tiripano'}},
#     {48.5: {'non_striker': 'RP Burl',
#       'bowler': 'TJ Murtagh',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'DT Tiripano',
#       'wicket': {'player_out': 'DT Tiripano', 'kind': 'bowled'}}},
#     {48.6: {'non_striker': 'RP Burl',
#       'bowler': 'TJ Murtagh',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'KM Jarvis'}},
#     {49.1: {'non_striker': 'KM Jarvis',
#       'bowler': 'MR Adair',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'RP Burl'}},
#     {49.2: {'non_striker': 'KM Jarvis',
#       'bowler': 'MR Adair',
#       'runs': {'extras': 0, 'total': 2, 'batsman': 2},
#       'batsman': 'RP Burl'}},
#     {49.3: {'non_striker': 'KM Jarvis',
#       'bowler': 'MR Adair',
#       'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#       'batsman': 'RP Burl'}},
#     {49.4: {'non_striker': 'KM Jarvis',
#       'bowler': 'MR Adair',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'RP Burl'}},
#     {49.5: {'non_striker': 'KM Jarvis',
#       'bowler': 'MR Adair',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'RP Burl',
#       'wicket': {'player_out': 'RP Burl', 'kind': 'run out'}}},
#     {49.6: {'non_striker': 'KM Jarvis',
#       'bowler': 'MR Adair',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'TL Chatara'}}]}}]

# %%
c=1
for i in df['match_id'].unique():
    if(i==c):
        pass
    else:
        print(c)
        c+=1
        while(i!=c):
            print(c)
            c+=1
    c+=1

#no match id is missing

# %%
df.shape
# Out:
# (2033, 37)

# %%
df_copy=df.copy()

# %%
count = 1
c=0
ball_of_match = []
batsman = []
non_striker=[]
bowler = []
runs = []
player_of_dismissed = []
teams = []
batting_team = []
match_id = []
city = []
venue = []
delivery_df = pd.DataFrame()
for index, row in df.iterrows():
    count+=1
    for ball in row['innings'][0]['1st innings']['deliveries']:
        for key,val in ball.items():
            ball_of_match.append(key)
            batsman.append(val['batsman'])
            non_striker.append(val['non_striker'])
            bowler.append(val['bowler'])
            runs.append(val['runs']['total'])
            try:
                player_of_dismissed.append(val['wicket']['player_out'])
            except:
                player_of_dismissed.append('0')
            teams.append(row['info.teams'])
            batting_team.append(row['innings'][0]['1st innings']['team'])
            match_id.append(row['match_id'])
            city.append(row['info.city'])
            venue.append(row['info.venue'])

# %%
df= pd.DataFrame({
            'match_id':match_id,
            'teams':teams,
            'batting_team':batting_team,
            'ball':ball_of_match,
            'batsman':batsman,
            'non_striker':non_striker,
            'bowler':bowler,
            'runs':runs,
            'player_dismissed':player_of_dismissed,
            'city':city,
            'venue':venue
        })

# %%
df.head()
# Out:
#    match_id                teams batting_team  ball      batsman  non_striker
# 0         1  [Ireland, Zimbabwe]      Ireland   0.1  PR Stirling  JA McCollum  \
# 1         1  [Ireland, Zimbabwe]      Ireland   0.2  PR Stirling  JA McCollum
# 2         1  [Ireland, Zimbabwe]      Ireland   0.3  PR Stirling  JA McCollum
# 3         1  [Ireland, Zimbabwe]      Ireland   0.4  PR Stirling  JA McCollum
# 4         1  [Ireland, Zimbabwe]      Ireland   0.5  PR Stirling  JA McCollum
#
#       bowler  runs player_dismissed     city
# 0  KM Jarvis     0                0  Belfast  \
# 1  KM Jarvis     0                0  Belfast
# 2  KM Jarvis     0                0  Belfast
# 3  KM Jarvis     0                0  Belfast
# 4  KM Jarvis     0                0  Belfast
#
#                                   venue
# 0  Civil Service Cricket Club, Stormont
# 1  Civil Service Cricket Club, Stormont
# 2  Civil Service Cricket Club, Stormont
# 3  Civil Service Cricket Club, Stormont
# 4  Civil Service Cricket Club, Stormont

# %%
df.shape
# Out:
# (588828, 11)

# %%
df['city'].isnull().sum()
# Out:
# 96830

# %%
df['venue'].isnull().sum()
# Out:
# 0

# %%
df['venue'].value_counts()
# Out:
# venue
# Shere Bangla National Stadium                      25458
# Harare Sports Club                                 21412
# R Premadasa Stadium                                14099
# County Ground                                      12324
# Sheikh Zayed Stadium                               12119
#                                                    ...
# Affies Park                                          271
# Toronto Cricket                                      211
# Greenfield International Stadium                     198
# Darren Sammy National Cricket Stadium, St Lucia      179
# Providence Stadium, Guyana                            80
# Name: count, Length: 215, dtype: int64

# %%
df['batting_team'].unique()
# Out:
# array(['Ireland', 'Bangladesh', 'Pakistan', 'West Indies', 'England',
#        'Australia', 'New Zealand', 'South Africa', 'Scotland', 'India',
#        'Zimbabwe', 'Sri Lanka', 'Afghanistan', 'Namibia',
#        'United Arab Emirates', 'Kenya', 'Papua New Guinea', 'Netherlands',
#        'Bermuda', 'United States of America', 'Africa XI', 'Asia XI',
#        'Nepal', 'Canada', 'Hong Kong', 'Oman'], dtype=object)

# %%
df['batting_team'].value_counts()
# Out:
# batting_team
# Australia                   72878
# Sri Lanka                   67959
# India                       59363
# England                     56518
# South Africa                51826
# Pakistan                    51755
# New Zealand                 50018
# West Indies                 43377
# Bangladesh                  36120
# Zimbabwe                    29799
# Ireland                     15628
# Afghanistan                 15616
# Scotland                     9742
# United Arab Emirates         5473
# Kenya                        3192
# Papua New Guinea             2991
# Canada                       2722
# Netherlands                  2656
# Hong Kong                    2271
# Bermuda                      2207
# United States of America     2180
# Namibia                      1378
# Nepal                        1130
# Asia XI                       934
# Oman                          615
# Africa XI                     480
# Name: count, dtype: int64

# %%
def bowl_team(rows):
    for i in rows['teams']:
        if i != rows['batting_team']:
            return i

# %%
df['bowling_team']=df.apply(bowl_team,axis=1)

# %%
df.head(5)
# Out:
#    match_id                teams batting_team  ball      batsman  non_striker
# 0         1  [Ireland, Zimbabwe]      Ireland   0.1  PR Stirling  JA McCollum  \
# 1         1  [Ireland, Zimbabwe]      Ireland   0.2  PR Stirling  JA McCollum
# 2         1  [Ireland, Zimbabwe]      Ireland   0.3  PR Stirling  JA McCollum
# 3         1  [Ireland, Zimbabwe]      Ireland   0.4  PR Stirling  JA McCollum
# 4         1  [Ireland, Zimbabwe]      Ireland   0.5  PR Stirling  JA McCollum
#
#       bowler  runs player_dismissed     city
# 0  KM Jarvis     0                0  Belfast  \
# 1  KM Jarvis     0                0  Belfast
# 2  KM Jarvis     0                0  Belfast
# 3  KM Jarvis     0                0  Belfast
# 4  KM Jarvis     0                0  Belfast
#
#                                   venue bowling_team
# 0  Civil Service Cricket Club, Stormont     Zimbabwe
# 1  Civil Service Cricket Club, Stormont     Zimbabwe
# 2  Civil Service Cricket Club, Stormont     Zimbabwe
# 3  Civil Service Cricket Club, Stormont     Zimbabwe
# 4  Civil Service Cricket Club, Stormont     Zimbabwe

# %%
df.drop(columns=['teams'],inplace=True)

# %%
df.sample(5)
# Out:
#         match_id  batting_team  ball       batsman    non_striker
# 415862      1433         India   4.2      S Dhawan        V Kohli  \
# 145457       500      Pakistan  32.2  Javeria Khan  Bismah Maroof
# 386454      1333  South Africa  24.3     H Klaasen    K Verreynne
# 285599       987     Australia  13.4     DA Warner       JA Burns
# 449279      1547       England  42.6    EJG Morgan         MM Ali
#
#                 bowler  runs player_dismissed           city
# 415862       JO Holder     0                0  Visakhapatnam  \
# 145457  EAJ Richardson     0                0         Dublin
# 386454      PJ Cummins     0                0          Paarl
# 285599     SR Thompson     1                0        Belfast
# 449279     Imran Tahir     1                0          Leeds
#
#                                                     venue  bowling_team
# 415862  Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket St...   West Indies
# 145457                                  YMCA Cricket Club       Ireland
# 386454                                        Boland Park     Australia
# 285599               Civil Service Cricket Club, Stormont       Ireland
# 449279                                         Headingley  South Africa

# %%
# Australia                   72878
# Sri Lanka                   67959
# India                       59363
# England                     56518
# South Africa                51826
# Pakistan                    51755
# New Zealand                 50018
# West Indies                 43377
# Bangladesh                  36120
# Zimbabwe                    29799
# Ireland                     15628
# Afghanistan                 15616
# Scotland                     9742
# United Arab Emirates         5473

selected_teams=['Australia','Sri Lanka','India','England','South Africa','Pakistan','New Zealand','West Indies',
               'Bangladesh','Zimbabwe','Ireland','Afghanistan','Scotland','United Arab Emirates']

# %%
df=df[df['batting_team'].isin(selected_teams)]
df=df[df['bowling_team'].isin(selected_teams)]

# %%
df.shape
# Out:
# (551130, 11)

# %%
df.head()
# Out:
#    match_id batting_team  ball      batsman  non_striker     bowler  runs
# 0         1      Ireland   0.1  PR Stirling  JA McCollum  KM Jarvis     0  \
# 1         1      Ireland   0.2  PR Stirling  JA McCollum  KM Jarvis     0
# 2         1      Ireland   0.3  PR Stirling  JA McCollum  KM Jarvis     0
# 3         1      Ireland   0.4  PR Stirling  JA McCollum  KM Jarvis     0
# 4         1      Ireland   0.5  PR Stirling  JA McCollum  KM Jarvis     0
#
#   player_dismissed     city                                 venue bowling_team
# 0                0  Belfast  Civil Service Cricket Club, Stormont     Zimbabwe
# 1                0  Belfast  Civil Service Cricket Club, Stormont     Zimbabwe
# 2                0  Belfast  Civil Service Cricket Club, Stormont     Zimbabwe
# 3                0  Belfast  Civil Service Cricket Club, Stormont     Zimbabwe
# 4                0  Belfast  Civil Service Cricket Club, Stormont     Zimbabwe

# %%
final_df = df[['match_id','batting_team','bowling_team','ball','runs','player_dismissed','city','venue']]

# %%
final_df.head()
# Out:
#    match_id batting_team bowling_team  ball  runs player_dismissed     city
# 0         1      Ireland     Zimbabwe   0.1     0                0  Belfast  \
# 1         1      Ireland     Zimbabwe   0.2     0                0  Belfast
# 2         1      Ireland     Zimbabwe   0.3     0                0  Belfast
# 3         1      Ireland     Zimbabwe   0.4     0                0  Belfast
# 4         1      Ireland     Zimbabwe   0.5     0                0  Belfast
#
#                                   venue
# 0  Civil Service Cricket Club, Stormont
# 1  Civil Service Cricket Club, Stormont
# 2  Civil Service Cricket Club, Stormont
# 3  Civil Service Cricket Club, Stormont
# 4  Civil Service Cricket Club, Stormont

# %%
pickle.dump(final_df,open('dataset_level2.pkl','wb'))
